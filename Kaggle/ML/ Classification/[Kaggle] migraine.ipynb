# %%
import os

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from pycaret.classification import *
from matplotlib import pyplot as plt
from sklearn.metrics import *
import seaborn as sns
import pandas as pd
import numpy as np

# %%
SEP       = os.path.sep
ROOT_PATH = SEP.join(os.getcwd().split(SEP)[:-4])
DATA_PATH = f'{ROOT_PATH}/Datasets/migraine/migraine_data.csv'

# %%
def multi_roc_auc_score(gt, pred, average = 'macro'):
    
    src_lb       = set(gt)
    roc_auc_dict = {}
    
    for label in src_lb:
        dst_lb      = [lb for lb in src_lb if lb != label]
        new_gt_lb   = [0 if lb in dst_lb else 1 for lb in gt]
        new_pred_lb = [0 if lb in dst_lb else 1 for lb in pred]
        
        roc_auc             = roc_auc_score(new_gt_lb, new_pred_lb, average = average)
        roc_auc_dict[label] = f'{roc_auc:.2f}'
        
    return roc_auc_dict

# %%
df = pd.read_csv(DATA_PATH)
df.sample(3).T
# Out:
#                                     181                         16   \
# Age                                  58                          40
# Duration                              1                           3
# Frequency                             1                           1
# Location                              1                           1
# Character                             1                           1
# Intensity                             3                           3
# Nausea                                1                           1
# Vomit                                 0                           0
# Phonophobia                           1                           1
# Photophobia                           1                           1
# Visual                                1                           4
# Sensory                               0                           0
# Dysphasia                             0                           0
# Dysarthria                            0                           0
# Vertigo                               0                           1
# Tinnitus                              0                           0
# Hypoacusis                            0                           0
# Diplopia                              0                           0
# Defect                                0                           0
# Ataxia                                0                           0
# Conscience                            0                           0
# Paresthesia                           0                           0
# DPF                                   1                           1
# Type         Typical aura with migraine  Typical aura with migraine
#
#                                     278
# Age                                  33
# Duration                              1
# Frequency                             2
# Location                              1
# Character                             1
# Intensity                             3
# Nausea                                1
# Vomit                                 0
# Phonophobia                           1
# Photophobia                           1
# Visual                                0
# Sensory                               2
# Dysphasia                             0
# Dysarthria                            0
# Vertigo                               0
# Tinnitus                              0
# Hypoacusis                            0
# Diplopia                              0
# Defect                                0
# Ataxia                                0
# Conscience                            0
# Paresthesia                           0
# DPF                                   0
# Type         Typical aura with migraine

# %%
type_   = set(sorted(df.Type))
ages    = set(sorted(df.Age))

_, axes = plt.subplots(1, len(type_), figsize = (5*len(type_) + 2, 5))
for ax, t in zip(axes, type_):
    
    df_ = df[df.Type == t]
    ax.hist(df_.Age, alpha = 0.7)
    ax.set_title(t)

# %%
le      = LabelEncoder()
df.Type = le.fit_transform(df.Type)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          400 non-null    int64
#  1   Duration     400 non-null    int64
#  2   Frequency    400 non-null    int64
#  3   Location     400 non-null    int64
#  4   Character    400 non-null    int64
#  5   Intensity    400 non-null    int64
#  6   Nausea       400 non-null    int64
#  7   Vomit        400 non-null    int64
#  8   Phonophobia  400 non-null    int64
#  9   Photophobia  400 non-null    int64
#  10  Visual       400 non-null    int64
#  11  Sensory      400 non-null    int64
#  12  Dysphasia    400 non-null    int64
#  13  Dysarthria   400 non-null    int64
#  14  Vertigo      400 non-null    int64
#  15  Tinnitus     400 non-null    int64
#  16  Hypoacusis   400 non-null    int64
#  17  Diplopia     400 non-null    int64
#  18  Defect       400 non-null    int64
#  19  Ataxia       400 non-null    int64
#  20  Conscience   400 non-null    int64
#  21  Paresthesia  400 non-null    int64
#  22  DPF          400 non-null    int64
#  23  Type         400 non-null    int64
# dtypes: int64(24)
# memory usage: 75.1 KB

# %%
_, ax = plt.subplots(figsize = (17, 17))
mask  = np.triu(df.corr())
sns.heatmap(df.corr(), mask = mask, annot = True, cmap = 'BuPu')
# Out:
# <Axes: >

# %%
drop_col = ['Age', 'Nausea', 'Phonophobia', 'Photophobia', 'Dysarthria']
y        = df.Type
x        = df.drop(drop_col + ['Type'], axis = 1)
x.sample(3).T
# Out:
#              397  227  219
# Duration       3    1    2
# Frequency      2    2    2
# Location       1    1    1
# Character      1    1    1
# Intensity      3    2    3
# Vomit          0    0    1
# Visual         1    2    2
# Sensory        0    0    1
# Dysphasia      0    0    0
# Vertigo        1    0    0
# Tinnitus       0    0    0
# Hypoacusis     0    0    0
# Diplopia       0    0    0
# Defect         1    0    0
# Ataxia         0    0    0
# Conscience     0    0    0
# Paresthesia    0    0    0
# DPF            1    0    0

# %%
plt.scatter(np.array(x)[:, 6], np.array(y[:]))
plt.xlabel('Visual')
plt.ylabel('Type')
# Out:
# Text(0, 0.5, 'Type')

# %%
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size = 0.2, stratify = y,
                                                    shuffle = y, random_state = 42)

# %%
rf = RandomForestClassifier()
rf.fit(train_x, train_y)
# Out:
# RandomForestClassifier()

# %%
pred = rf.predict(train_x)
print(f'[TRAIN]')
print('accuracy : ', rf.score(train_x, train_y))
print(classification_report(pred, train_y))

pred = rf.predict(test_x)
print(f'[TEST]')
print('accuracy : ', rf.score(test_x, test_y))
print(classification_report(pred, test_y))
# Out:
# [TRAIN]
# accuracy :  0.984375
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.84      0.94      0.89        17
#            2       1.00      1.00      1.00        48
#            3       1.00      0.93      0.97        15
#            4       0.91      1.00      0.95        10
#            5       0.99      0.98      0.99       200
#            6       1.00      1.00      1.00        16
#
#     accuracy                           0.98       320
#    macro avg       0.96      0.98      0.97       320
# weighted avg       0.99      0.98      0.98       320
#
# [TEST]
# accuracy :  0.9125
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         3
#            1       0.60      0.60      0.60         5
#            2       1.00      0.92      0.96        13
#            3       0.67      0.67      0.67         3
#            4       0.67      1.00      0.80         2
#            5       0.96      0.94      0.95        50
#            6       1.00      1.00      1.00         4
#
#     accuracy                           0.91        80
#    macro avg       0.81      0.88      0.83        80
# weighted avg       0.92      0.91      0.91        80

# %%
df_          = df.drop(drop_col, axis = 1)
df_tr, df_te = train_test_split(df_, test_size = 0.2, shuffle = True, random_state = 42)
caret        = setup(data = df_tr, target = 'Type', session_id = 999,
                     fix_imbalance = True, fix_imbalance_method = 'smotetomek')
# Out:
# <style type="text/css">
# #T_a4e80_row8_col1, #T_a4e80_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a4e80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4e80_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a4e80_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4e80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4e80_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a4e80_row0_col1" class="data row0 col1" >999</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4e80_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a4e80_row1_col1" class="data row1 col1" >Type</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4e80_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a4e80_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a4e80_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a4e80_row3_col1" class="data row3 col1" >(320, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a4e80_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a4e80_row4_col1" class="data row4 col1" >(1069, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a4e80_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a4e80_row5_col1" class="data row5 col1" >(973, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a4e80_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a4e80_row6_col1" class="data row6 col1" >(96, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a4e80_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a4e80_row7_col1" class="data row7 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a4e80_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_a4e80_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a4e80_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_a4e80_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a4e80_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_a4e80_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a4e80_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_a4e80_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a4e80_row12_col0" class="data row12 col0" >Fix imbalance</td>
#       <td id="T_a4e80_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a4e80_row13_col0" class="data row13 col0" >Fix imbalance method</td>
#       <td id="T_a4e80_row13_col1" class="data row13 col1" >smotetomek</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a4e80_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_a4e80_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a4e80_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_a4e80_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a4e80_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_a4e80_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a4e80_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_a4e80_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a4e80_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_a4e80_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a4e80_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_a4e80_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a4e80_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a4e80_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_a4e80_row20_col1" class="data row20 col1" >9c87</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model  = compare_models()
final_model = finalize_model(best_model)

pred = predict_model(final_model, df_tr)
pred = predict_model(final_model, df_te)
# Out:
# <style type="text/css">
# #T_08326 th {
#   text-align: left;
# }
# #T_08326_row0_col0, #T_08326_row0_col2, #T_08326_row1_col0, #T_08326_row1_col1, #T_08326_row1_col2, #T_08326_row1_col3, #T_08326_row1_col4, #T_08326_row1_col5, #T_08326_row1_col6, #T_08326_row1_col7, #T_08326_row2_col0, #T_08326_row2_col1, #T_08326_row2_col2, #T_08326_row2_col3, #T_08326_row2_col4, #T_08326_row2_col5, #T_08326_row2_col6, #T_08326_row2_col7, #T_08326_row3_col0, #T_08326_row3_col1, #T_08326_row3_col3, #T_08326_row3_col4, #T_08326_row3_col5, #T_08326_row3_col6, #T_08326_row3_col7, #T_08326_row4_col0, #T_08326_row4_col1, #T_08326_row4_col2, #T_08326_row4_col3, #T_08326_row4_col4, #T_08326_row4_col5, #T_08326_row4_col6, #T_08326_row4_col7, #T_08326_row5_col0, #T_08326_row5_col1, #T_08326_row5_col2, #T_08326_row5_col3, #T_08326_row5_col4, #T_08326_row5_col5, #T_08326_row5_col6, #T_08326_row5_col7, #T_08326_row6_col0, #T_08326_row6_col1, #T_08326_row6_col2, #T_08326_row6_col3, #T_08326_row6_col4, #T_08326_row6_col5, #T_08326_row6_col6, #T_08326_row6_col7, #T_08326_row7_col0, #T_08326_row7_col1, #T_08326_row7_col2, #T_08326_row7_col3, #T_08326_row7_col4, #T_08326_row7_col5, #T_08326_row7_col6, #T_08326_row7_col7, #T_08326_row8_col0, #T_08326_row8_col1, #T_08326_row8_col2, #T_08326_row8_col3, #T_08326_row8_col4, #T_08326_row8_col5, #T_08326_row8_col6, #T_08326_row8_col7, #T_08326_row9_col0, #T_08326_row9_col1, #T_08326_row9_col2, #T_08326_row9_col3, #T_08326_row9_col4, #T_08326_row9_col5, #T_08326_row9_col6, #T_08326_row9_col7, #T_08326_row10_col0, #T_08326_row10_col1, #T_08326_row10_col2, #T_08326_row10_col3, #T_08326_row10_col4, #T_08326_row10_col5, #T_08326_row10_col6, #T_08326_row10_col7, #T_08326_row11_col0, #T_08326_row11_col1, #T_08326_row11_col2, #T_08326_row11_col3, #T_08326_row11_col4, #T_08326_row11_col5, #T_08326_row11_col6, #T_08326_row11_col7, #T_08326_row12_col0, #T_08326_row12_col1, #T_08326_row12_col2, #T_08326_row12_col3, #T_08326_row12_col4, #T_08326_row12_col5, #T_08326_row12_col6, #T_08326_row12_col7, #T_08326_row13_col0, #T_08326_row13_col1, #T_08326_row13_col2, #T_08326_row13_col3, #T_08326_row13_col4, #T_08326_row13_col5, #T_08326_row13_col6, #T_08326_row13_col7, #T_08326_row14_col0, #T_08326_row14_col1, #T_08326_row14_col2, #T_08326_row14_col3, #T_08326_row14_col4, #T_08326_row14_col5, #T_08326_row14_col6, #T_08326_row14_col7 {
#   text-align: left;
# }
# #T_08326_row0_col1, #T_08326_row0_col3, #T_08326_row0_col4, #T_08326_row0_col5, #T_08326_row0_col6, #T_08326_row0_col7, #T_08326_row3_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_08326_row0_col8, #T_08326_row1_col8, #T_08326_row2_col8, #T_08326_row3_col8, #T_08326_row4_col8, #T_08326_row5_col8, #T_08326_row6_col8, #T_08326_row7_col8, #T_08326_row9_col8, #T_08326_row10_col8, #T_08326_row11_col8, #T_08326_row12_col8, #T_08326_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_08326_row8_col8, #T_08326_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_08326">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08326_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_08326_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_08326_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_08326_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_08326_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_08326_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_08326_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_08326_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_08326_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08326_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_08326_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_08326_row0_col1" class="data row0 col1" >0.9016</td>
#       <td id="T_08326_row0_col2" class="data row0 col2" >0.4861</td>
#       <td id="T_08326_row0_col3" class="data row0 col3" >0.9016</td>
#       <td id="T_08326_row0_col4" class="data row0 col4" >0.8801</td>
#       <td id="T_08326_row0_col5" class="data row0 col5" >0.8861</td>
#       <td id="T_08326_row0_col6" class="data row0 col6" >0.8272</td>
#       <td id="T_08326_row0_col7" class="data row0 col7" >0.8325</td>
#       <td id="T_08326_row0_col8" class="data row0 col8" >0.1550</td>
#     </tr>
#     <tr>
#       <th id="T_08326_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_08326_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_08326_row1_col1" class="data row1 col1" >0.8974</td>
#       <td id="T_08326_row1_col2" class="data row1 col2" >0.4766</td>
#       <td id="T_08326_row1_col3" class="data row1 col3" >0.8974</td>
#       <td id="T_08326_row1_col4" class="data row1 col4" >0.8793</td>
#       <td id="T_08326_row1_col5" class="data row1 col5" >0.8812</td>
#       <td id="T_08326_row1_col6" class="data row1 col6" >0.8220</td>
#       <td id="T_08326_row1_col7" class="data row1 col7" >0.8293</td>
#       <td id="T_08326_row1_col8" class="data row1 col8" >0.1370</td>
#     </tr>
#     <tr>
#       <th id="T_08326_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_08326_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_08326_row2_col1" class="data row2 col1" >0.8794</td>
#       <td id="T_08326_row2_col2" class="data row2 col2" >0.4867</td>
#       <td id="T_08326_row2_col3" class="data row2 col3" >0.8794</td>
#       <td id="T_08326_row2_col4" class="data row2 col4" >0.8452</td>
#       <td id="T_08326_row2_col5" class="data row2 col5" >0.8567</td>
#       <td id="T_08326_row2_col6" class="data row2 col6" >0.7876</td>
#       <td id="T_08326_row2_col7" class="data row2 col7" >0.7962</td>
#       <td id="T_08326_row2_col8" class="data row2 col8" >0.1560</td>
#     </tr>
#     <tr>
#       <th id="T_08326_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_08326_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_08326_row3_col1" class="data row3 col1" >0.8792</td>
#       <td id="T_08326_row3_col2" class="data row3 col2" >0.4871</td>
#       <td id="T_08326_row3_col3" class="data row3 col3" >0.8792</td>
#       <td id="T_08326_row3_col4" class="data row3 col4" >0.8586</td>
#       <td id="T_08326_row3_col5" class="data row3 col5" >0.8617</td>
#       <td id="T_08326_row3_col6" class="data row3 col6" >0.7909</td>
#       <td id="T_08326_row3_col7" class="data row3 col7" >0.7983</td>
#       <td id="T_08326_row3_col8" class="data row3 col8" >0.1770</td>
#     </tr>
#     <tr>
#       <th id="T_08326_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_08326_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_08326_row4_col1" class="data row4 col1" >0.8704</td>
#       <td id="T_08326_row4_col2" class="data row4 col2" >0.4851</td>
#       <td id="T_08326_row4_col3" class="data row4 col3" >0.8704</td>
#       <td id="T_08326_row4_col4" class="data row4 col4" >0.8392</td>
#       <td id="T_08326_row4_col5" class="data row4 col5" >0.8484</td>
#       <td id="T_08326_row4_col6" class="data row4 col6" >0.7734</td>
#       <td id="T_08326_row4_col7" class="data row4 col7" >0.7799</td>
#       <td id="T_08326_row4_col8" class="data row4 col8" >0.2290</td>
#     </tr>
#     <tr>
#       <th id="T_08326_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_08326_row5_col0" class="data row5 col0" >CatBoost Classifier</td>
#       <td id="T_08326_row5_col1" class="data row5 col1" >0.8569</td>
#       <td id="T_08326_row5_col2" class="data row5 col2" >0.4810</td>
#       <td id="T_08326_row5_col3" class="data row5 col3" >0.8569</td>
#       <td id="T_08326_row5_col4" class="data row5 col4" >0.8324</td>
#       <td id="T_08326_row5_c
# <style type="text/css">
# </style>
# <table id="T_0109d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0109d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0109d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0109d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0109d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0109d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0109d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0109d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0109d_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0109d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0109d_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_0109d_row0_col1" class="data row0 col1" >0.9812</td>
#       <td id="T_0109d_row0_col2" class="data row0 col2" >0.9996</td>
#       <td id="T_0109d_row0_col3" class="data row0 col3" >0.9812</td>
#       <td id="T_0109d_row0_col4" class="data row0 col4" >0.9823</td>
#       <td id="T_0109d_row0_col5" class="data row0 col5" >0.9813</td>
#       <td id="T_0109d_row0_col6" class="data row0 col6" >0.9681</td>
#       <td id="T_0109d_row0_col7" class="data row0 col7" >0.9682</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_8a4b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a4b0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8a4b0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8a4b0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8a4b0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8a4b0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8a4b0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8a4b0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8a4b0_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a4b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a4b0_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_8a4b0_row0_col1" class="data row0 col1" >0.9000</td>
#       <td id="T_8a4b0_row0_col2" class="data row0 col2" >0.9725</td>
#       <td id="T_8a4b0_row0_col3" class="data row0 col3" >0.9000</td>
#       <td id="T_8a4b0_row0_col4" class="data row0 col4" >0.9275</td>
#       <td id="T_8a4b0_row0_col5" class="data row0 col5" >0.9084</td>
#       <td id="T_8a4b0_row0_col6" class="data row0 col6" >0.8376</td>
#       <td id="T_8a4b0_row0_col7" class="data row0 col7" >0.8418</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model  = compare_models(n_select = 3)
blend_model = blend_models(best_model)
final_model = finalize_model(blend_model)

pred_tr     = predict_model(final_model, df_tr)
pred_te     = predict_model(final_model, df_te)
# Out:
# <style type="text/css">
# #T_1f314 th {
#   text-align: left;
# }
level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_1f314_row5_col0" class="data row5 col0" >CatBoost Classifier</td>
#       <td id="T_1f314_row5_col1" class="data row5 col1" >0.8569</td>
#       <td id="T_1f314_row5_col2" class="data row5 col2" >0.4810</td>
#       <td id="T_1f314_row5_col3" class="data row5 col3" >0.8569</td>
#       <td id="T_1f314_row5_col4" class="data row5 col4" >0.8324</td>
#       <td id="T_1f314_row5_c
# <style type="text/css">
# #T_a6190_row10_col0, #T_a6190_row10_col1, #T_a6190_row10_col2, #T_a6190_row10_col3, #T_a6190_row10_col4, #T_a6190_row10_col5, #T_a6190_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a6190">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6190_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a6190_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a6190_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a6190_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a6190_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a6190_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a6190_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6190_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6190_row0_col0" class="data row0 col0" >0.9565</td>
#       <td id="T_a6190_row0_col1" class="data row0 col1" >0.9979</td>
#       <td id="T_a6190_row0_col2" class="data row0 col2" >0.9565</td>
#       <td id="T_a6190_row0_col3" class="data row0 col3" >0.9594</td>
#       <td id="T_a6190_row0_col4" class="data row0 col4" >0.9500</td>
#       <td id="T_a6190_row0_col5" class="data row0 col5" >0.9243</td>
#       <td id="T_a6190_row0_col6" class="data row0 col6" >0.9282</td>
#     </tr>
#     <tr>
#       <th id="T_a6190_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6190_row1_col0" class="data row1 col0" >0.9130</td>
#       <td id="T_a6190_row1_col1" class="data row1 col1" >0.9608</td>
#       <td id="T_a6190_row1_col2" class="data row1 col2" >0.9130</td>
#       <td id="T_a6190_row1_col3" class="data row1 col3" >0.8942</td>
#       <td id="T_a6190_row1_col4" class="data row1 col4" >0.8921</td>
#       <td id="T_a6190_row1_col5" class="data row1 col5" >0.8487</td>
#       <td id="T_a6190_row1_col6" class="data row1 col6" >0.8552</td>
#     </tr>
#     <tr>
#       <th id="T_a6190_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6190_row2_col0" class="data row2 col0" >0.9130</td>
#       <td id="T_a6190_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_a6190_row2_col2" class="data row2 col2" >0.9130</td>
#       <td id="T_a6190_row2_col3" class="data row2 col3" >0.8507</td>
#       <td id="T_a6190_row2_col4" class="data row2 col4" >0.8776</td>
#       <td id="T_a6190_row2_col5" class="data row2 col5" >0.8482</td>
#       <td id="T_a6190_row2_col6" class="data row2 col6" >0.8576</td>
#     </tr>
#     <tr>
#       <th id="T_a6190_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6190_row3_col0" class="data row3 col0" >0.9130</td>
#       <td id="T_a6190_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_a6190_row3_col2" class="data row3 col2" >0.9130</td>
#       <td id="T_a6190_row3_col3" class="data row3 col3" >0.8942</td>
#       <td id="T_a6190_row3_col4" class="data row3 col4" >0.8921</td>
#       <td id="T_a6190_row3_col5" class="data row3 col5" >0.8477</td>
#       <td id="T_a6190_row3_col6" class="data row3 col6" >0.8543</td>
#     </tr>
#     <tr>
#       <th id="T_a6190_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6190_row4_col0" class="data row4 col0" >0.9545</td>
#       <td id="T_a6190_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_a6190_row4_col2" class="data row4 col2" >0.9545</td>
#       <td id="T_a6190_row4_col3" class="data row4 col3" >0.9121</td>
#       <td id="T_a6190_row4_col4" class="data row4 col4" >0.9326</td>
#       <td id="T_a6190_row4_col5" class="data row4 col5" >0.9137</td>
#       <td id="T_a6190_row4_col6" class="data row4 col6" >0.9187</td>
#     </tr>
#     <tr>
#       <th id="T_a6190_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6190_row5_col0" class="data row5 col0" >0.8636</td>
#       <td id="T_a6190_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_a6190_row5_col2" class="data row5 col2" >0.8636</td>
#       <td id="T_a6190_row5_col3" class="data row5 col3" >0.8409</td>
#       <td id="T_a6190_row5_col4" class="data row5 col4" >0.8485</td>
#       <td id="T_a6190_row5_col5" class="data row5 col5" >0.7537</td>
#       <td id="T_a6190_row5_col6" class="data row5 col6" >0.7566</td>
#     </tr>
#     <tr>
#       <th id="T_a6190_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a6190_row6_col0" class="data row6 col0" >0.8636</td>
#       <td id="T_a6190_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_a6190_row6_col2" class="data row6 col2" >0.8636</td>
#       <td id="T_a6190_row6_col3" class="data row6 col3" >0.8636</td>
#       <td id="T_a6190_row6_col4" class="data row6 col4" >0.8636</td>
#       <td id="T_a6190_row6_col5" class="data row6 col5" >0.7537</td>
#       <td id="T_a6190_row6_col6" class="data row6 col6" >0.7566</td>
#     </tr>
#     <tr>
#       <th id="T_a6190_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a6190_row7_col0" class="data row7 col0" >0.8636</td>
#       <td id="T_a6190_row7_col1" class="data row7 col1" >0.9245</td>
#       <td id="T_a6190_row7_col2" class="data row7 col2" >0.8636</td>
#       <td id="T_a6190_row7_col3" class="data row7 col3" >0.7644</td>
#       <td id="T_a6190_row7_col4" class="data row7 col4" >0.8071</td>
#       <td id="T_a6190_row7_col5" class="data row7 col5" >0.7452</td>
#       <td id="T_a6190_row7_col6" class="data row7 col6" >0.7558</td>
#     </tr>
#     <tr>
#       <th id="T_a6190_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a6190_row8_col0" class="data row8 col0" >0.9545</td>
#       <td id="T_a6190_row8_col1" class="data row8 col1" >0.9913</td>
#       <td id="T_a6190_row8_col2" class="data row8 col2" >0.9545</td>
#       <td id="T_a6190_row8_col3" class="data row8 col3" >0.9318</td>
#       <td id="T_a6190_row8_col4" class="data row8 col4" >0.9394</td>
#       <td id="T_a6190_row8_col5" class="data row8 col5" >0.9197</td>
#       <td id="T_a6190_row8_col6" class="data row8 col6" >0.9231</td>
#     </tr>
#     <tr>
#       <th id="T_a6190_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a6190_row9_col0" class="data row9 col0" >0.9091</td>
#       <td id="T_a6190_row9_col1" class="data row9 col1" >0.9885</td>
#       <td id="T_a6190_row9_col2" class="data row9 col2" >0.9091</td>
#       <td id="T_a6190_row9_col3" class="data row9 col3" >0.9242</td>
#       <td id="T_a6190_row9_col4" class="data row9 col4" >0.9082</td>
#       <td id="T_a6190_row9_col5" class="data row9 col5" >0.8581</td>
#       <td id="T_a6190_row9_col6" class="data row9 col6" >0.8668</td>
#     </tr>
#     <tr>
#       <th id="T_a6190_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a6190_row10_col0" class="data row10 col0" >0.9105</td>
#       <td id="T_a6190_row10_col1" class="data row10 col1" >0.4863</td>
#       <td id="T_a6190_row10_col2" class="data row10 col2" >0.9105</td>
#       <td id="T_a6190_row10_col3" class="data row10 col3" >0.8836</td>
#       <td id="T_a6190_row10_col4" class="data row10 col4" >0.8911</td>
#       <td id="T_a6190_row10_col5" class="data row10 col5" >0.8413</td>
#       <td id="T_a6190_row10_col6" class="data row10 col6" >0.8473</td>
#     </tr>
#     <tr>
#       <th id="T_a6190_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a6190_row11_col0" class="data row11 col0" >0.0355</td>
#       <td id="T_a6190_row11_col1" class="data row11 col1" >0.4867</td>
#       <td id="T_a6190_row11_col2" class="data row11 col2" >0.0355</td>
#       <td id="T_a6190_row11_col3" class="data row11 col3" >0.0532</td>
#       <td id="T_a6190_row11_col4
# <style type="text/css">
# </style>
# <table id="T_41f42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41f42_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_41f42_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_41f42_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_41f42_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_41f42_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_41f42_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_41f42_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_41f42_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41f42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41f42_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_41f42_row0_col1" class="data row0 col1" >0.9844</td>
#       <td id="T_41f42_row0_col2" class="data row0 col2" >0.9991</td>
#       <td id="T_41f42_row0_col3" class="data row0 col3" >0.9844</td>
#       <td id="T_41f42_row0_col4" class="data row0 col4" >0.9844</td>
#       <td id="T_41f42_row0_col5" class="data row0 col5" >0.9840</td>
#       <td id="T_41f42_row0_col6" class="data row0 col6" >0.9730</td>
#       <td id="T_41f42_row0_col7" class="data row0 col7" >0.9732</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3fe69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fe69_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3fe69_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3fe69_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3fe69_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3fe69_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3fe69_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3fe69_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3fe69_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fe69_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3fe69_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_3fe69_row0_col1" class="data row0 col1" >0.9250</td>
#       <td id="T_3fe69_row0_col2" class="data row0 col2" >0.9958</td>
#       <td id="T_3fe69_row0_col3" class="data row0 col3" >0.9250</td>
#       <td id="T_3fe69_row0_col4" class="data row0 col4" >0.9661</td>
#       <td id="T_3fe69_row0_col5" class="data row0 col5" >0.9366</td>
#       <td id="T_3fe69_row0_col6" class="data row0 col6" >0.8797</td>
#       <td id="T_3fe69_row0_col7" class="data row0 col7" >0.8860</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('[TRAIN]')
print(classification_report(pred_tr.prediction_label, df_tr.Type))
print(multi_roc_auc_score(pred_tr.prediction_label, df_tr.Type))

print('[TEST]')
print(classification_report(pred_te.prediction_label, df_te.Type))
print(multi_roc_auc_score(pred_te.prediction_label, df_te.Type))
# Out:
# [TRAIN]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       0.90      0.95      0.93        20
#            2       1.00      0.98      0.99        48
#            3       0.85      1.00      0.92        11
#            4       0.92      1.00      0.96        11
#            5       1.00      0.99      0.99       201
#            6       1.00      1.00      1.00        17
#
#     accuracy                           0.98       320
#    macro avg       0.95      0.99      0.97       320
# weighted avg       0.99      0.98      0.98       320
#
# {0: '1.00', 1: '0.97', 2: '0.99', 3: '1.00', 4: '1.00', 5: '0.99', 6: '1.00'}
# [TEST]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      0.43      0.60         7
#            2       1.00      1.00      1.00        13
#            3       0.75      1.00      0.86         3
#            4       1.00      0.50      0.67         4
#            5       0.90      1.00      0.95        44
#            6       1.00      1.00      1.00         3
#
#     accuracy                           0.93        80
#    macro avg       0.95      0.85      0.87        80
# weighted avg       0.93      0.93      0.91        80
#
# {0: '1.00', 1: '0.71', 2: '1.00', 3: '0.99', 4: '0.75', 5: '0.93', 6: '1.00'}
