# %%
from collections import Counter
import ast
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
ROOT_PATH = '/'.join(os.getcwd().split('/')[:-3])
DATA_PATH = f'{ROOT_PATH}/AI_study/dataset/KBO'

# %%
df = pd.read_csv(f'{DATA_PATH}/kbo_train.csv')
df
# Out:
#       age   AB  salary    war  hand2  cp    OPS   YOPS  YAB
# 0      24   52    2500 -0.055      1   2  0.509  0.580   79
# 1      25   79    2900 -0.441      1   2  0.580  0.784  154
# 2      26  154    6000  0.783      1   2  0.784  0.581  174
# 3      27  174    6000 -0.405      1   2  0.581  0.476   17
# 4      28   17    5500 -0.130      1   2  0.476  0.691   47
# ...   ...  ...     ...    ...    ...  ..    ...    ...  ...
# 1888   32  479   30000  3.315      1   5  0.867  0.768  395
# 1889   28  191    3100  0.215      2   9  0.684  0.154   13
# 1890   29   13    6200 -0.271      2   9  0.154  0.720  188
# 1891   27  279   50000  2.365      1   5  0.849  0.889  523
# 1892   28  523   50000  5.356      1   5  0.889  0.769  181
#
# [1893 rows x 9 columns]

# %%
sns.heatmap(df.corr(), cmap = 'BuPu', annot = True)
# Out:
# <AxesSubplot: >

# %%
y  = df['YOPS']
x  = df.drop(conf_mat = confusion_matrix(gt, preds)
conf_mat = pd.DataFrame(conf_mat, index = ['none', 'hate'], columns = ['none', 'hate'])
sns.heatmap(conf_mat, annot = True, cmap = 'BuPu', fmt = ',d'), axis = 1)
sns.heatmap(x.corr(), cmap = 'BuPu', annot = True)
# Out:
# <AxesSubplot: >

# %%
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size = 0.3, 
                                                    random_state = 99, shuffle = True)

# %%
model = LinearRegression()
model.fit(train_x, train_y)

train_score = model.score(train_x, train_y)
test_score  = model.score(test_x, test_y)

train_score, test_score
# Out:
# (0.25584255963754854, 0.2981754723169684)

# %%
valid_df = pd.read_csv(f'{DATA_PATH}/kbo_test.csv')
valid_y  = valid_df['YOPS']
valid_x  = valid_df.drop(['age', 'salary', 'hand2', 'cp', 'YOPS'], axis = 1)

model.score(valid_x, valid_y)
# Out:
# 0.045308895205579125

# %%
valid_x
# Out:
#      AB    war    OPS
# 0    89  0.493  0.732
# 1   132  0.189  0.706
# 2   395  2.170  0.694
# 3   332  1.765  0.678
# 4   462  3.497  0.714
# 5   377  2.706  0.736
# 6   404  2.532  0.735
# 7   564  5.260  0.910
# 8   445  1.813  0.806
# 9   381  5.024  0.982
# 10  178 -0.306  0.576
# 11  387  2.166  0.658
# 12  245  1.431  0.722
# 13  311  0.010  0.673
# 14  367  2.757  0.826
# 15  564  3.192  0.767
# 16  198  0.789  0.855
# 17  122  0.111  0.763
