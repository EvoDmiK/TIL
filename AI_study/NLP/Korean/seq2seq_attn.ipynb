# %% [markdown]
# <a href="https://colab.research.google.com/github/EvoDmiK/AI_study/blob/main/NLP/Korean/seq2seq_attn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import unicode_literals, print_function, division
import torch.nn.functional as F
from torch import optim
import torch.nn as nn
from io import open
import unicodedata
import random
import string
import torch
import re

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

SOS_token = 0
EOS_token = 1

# %%
ROOT_PATH = '/content/drive/MyDrive/Colab Notebooks'

# %%
class Lang:
  def __init__(self, name):

    self.name = name
    self.word2idx, self.word2cnt = {}, {}
    self.idx2word = {0 : 'SOS', 1 : 'EOS'}
    self.n_words = 2

  def add_sentence(self, senteces):
    for word in senteces.split(' '):
      self.add_word(word)

  def add_word(self, word):
    if word not in self.word2idx:
      self.word2idx[word] = self.n_words
      self.word2cnt[word] = 1
      self.idx2word[self.n_words] = word
      self.n_words += 1

    else:
      self.word2cnt[word] += 1

# %%
def preprocessing(string):

  ## 문자열 공백제거 ##
  string = string.strip()
  string = re.sub(r'[^ ㄱ-ㅣ가-힣.!?]+', r" ", string)
  return string

# %%
def read_texts(text_path, reverse = False):
  lines = open(text_path, encoding='utf-8').read().strip().split('\n')
  pairs = [[preprocessing(string) for string in line.split('\t\t\t')] for line in lines]

  if reverse:
    pairs = [list(reversed(pair)) for pair in pairs]
    input_corpus = Lang('dialect')
    output_corpus = Lang('standard')

  else:
    input_corpus = Lang('standard')
    output_corpus = Lang('dialect')

  return input_corpus, output_corpus, pairs

# %%
def prepare_dataset(text_path, reverse = False):
  input_corpus, output_corpus, pairs = read_texts(text_path, reverse)
  for pair in pairs:
    input_corpus.add_sentence(pair[0])
    output_corpus.add_sentence(pair[1])

  print(input_corpus.name, input_corpus.n_words)
  print(output_corpus.name, output_corpus.n_words)

  return input_corpus, output_corpus, pairs

text_path = f'{ROOT_PATH}/dataset/corpuses.txt'
dialect, standard, pairs = prepare_dataset(text_path, True)
# Out:
# dialect 266263
# standard 251671

# %%
random_pair = random.choice(pairs)
print(random_pair)
# Out:
# ['니야말로', '너야말로']

# %%
class Encoder(nn.Module):

  def __init__(self, input_size, hidden_size):
    super(Encoder, self).__init__()
    self.hidden_size = hidden_size

    self.embedding = nn.Embedding(input_size, hidden_size)
    self.gru = nn.GRU(hidden_size, hidden_size)

  def forward(self, input, hidden):
    embedded = self.embedding(input).view(1, 1, -1)
    output = embedded

    output, hidden = self.gru(output, hidden)
    return output, hidden

  def init_hidden(self):
    return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class Decoder(nn.Module):

  def __init__(self, hidden_size, output_size):
    super(Decoder, self).__init__()
    self.hidden_size = hidden_size

    self.embedding = nn.Embedding(output_size, hidden_size)
    self.gru = nn.GRU(hidden_size, hidden_size)
    self.out = nn.Linear(hidden_size, output_size)

    self.softmax = nn.LogSoftmax(dim = 1)

  def forward(self, input, hidden):
    output = self.embedding(input).view(1, 1, -1)
    output = F.relu(output)
    output, hidden = self.gru(output, hidden)
    output = self.softmax(self.out(output[0]))
    return output, hidden_size

  def init_hidden(self):
    return torch.zeros(1, 1, self.hidden_size, device = device)

# %%
class AttnDecoder(nn.Module):

  def __init__(self, hidden_size, output_size, dropout_p = 0.1, max_length = 70):
    super(AttnDecoder, self).__init__()
    self.hidden_size = hidden_size
    self.output_size = output_size
    self.dropout_p = dropout_p
    self.max_length = max_length

    self.embedding = nn.Embedding(self.output_size, self.hidden_size)
    self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
    self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
    self.dropout = nn.Dropout(self.dropout_p)
    self.gru = nn.GRU(self.hidden_size, self.hidden_size)
    self.out = nn.Linear(self.hidden_size, self.output_size)

  def forward(self, input, hidden, encoder_output):
    embedded = self.embedding(input).view(1, 1, -1)
    embedded = self.dropout(embedded)

    attn_weights = F.softmax(self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
    attn_applied = torch.bmm(attn_weights.unsqueeze(0), encoder_output.unsqueeze(0))

    output = torch.cat((embedded[0], attn_applied[0]), 1)
    output = self.attn_combine(output).unsqueeze(0)

    output = F.relu(output)
    output, hidden = self.gru(output, hidden)

    output = F.log_softmax(self.out(output[0]), dim=1)
    return output, hidden, attn_weights


  def init_hidden(self):
    return torch.zeros(1, 1, self.hidden_size, device = device)

# %%
def idxs_from_sentence(lang, sentence):
  return [lang.word2idx[word] for word in sentence.split(' ')]

def tensor_from_sentence(lang, sentence):
  idxs = idxs_from_sentence(lang,sentence)
  idxs.append(EOS_token)
  return torch.tensor(idxs, dtype=torch.long, device=device).view(-1, 1)

def tensors_from_pair(pair):
  standard_tensor = tensor_from_sentence(standard, pair[1])
  dialect_tensor = tensor_from_sentence(dialect, pair[0])

  return (dialect_tensor, standard_tensor)


print(pairs[5][0], idxs_from_sentence(dialect, pairs[5][1]))
# Out:
# 그러면 사실은 우리는 뭐 없어서 못 묵지. [46, 47, 48, 49, 50, 3, 21226]

# %%
teacher_forcing_ratio = 0.5

def train(input_tensor, label_tensor, encoder, decoder, encoder_optim,
          decoder_optim, loss_func, max_length = 70):
  
  encoder_hidden = encoder.init_hidden()

  encoder_optim.zero_grad()
  decoder_optim.zero_grad()

  input_length = input_tensor.size(0)
  label_length = label_tensor.size(0)

  encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device = device)
  loss = 0

  print(f'input_length : {input_length}')
  for ei in range(input_length):
    encoder_output, encoder_hidden = encoder(
        input_tensor[ei], encoder_hidden)
    encoder_outputs[ei] = encoder_output[0, 0]

  decoder_input = torch.tensor([[SOS_token]], device=device)
  decoder_hidden = decoder.init_hidden()

  use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

  ## teacher_forcing을 사용할 경우에는 레이블 값을 다음 입력으로 전달
  if use_teacher_forcing:
    for di in range(label_length):
      decoder_output, decoder_hidden, decoder_attn = decoder(
          decoder_input, decoder_hidden, encoder_outputs)
      loss += loss_func(decoder_output, label_tensor[di])

  ## teacher_forcing을 사용하지 않을 경우에는 자신의 예측을 다음 입력으로 전달
  else:
    for di in range(label_length):
      decoder_output, decoder_hidden, decoder_attn = decoder(
          decoder_input, decoder_hidden, encoder_outputs)
      topv, topi = decoder_output.topk(1)
      decoder_input = topi.squeeze().detach()

      loss += loss_func(decoder_output, label_tensor[di])
      if decoder_input.item() == EOS_token: break
  
  loss.backward()
  encoder_optim.step()
  decoder_optim.step()

  return loss.item() / label_length

# %%
import time, math

def as_minutes(seconds):
  minute = math.floor(seconds / 60)
  seconds -= minute * 60
  return f'{minute}min {seconds}sec'

def time_since(since, percent):
  now = time.time()
  spend = now - since
  es = spend / percent
  rs = es - spend
  return f'{as_minutes(spend)} (- {as_minutes(rs)})'

# %%
def train_iters(encoder, decoder, epochs, lr = 1e-2, print_every = 1000, plot_every = 100):
  start = time.time()

  plot_losses = []
  print_loss_total = 0
  plot_loss_total = 0

  encoder_optim = optim.SGD(encoder.parameters(), lr = lr)
  decoder_optim = optim.SGD(decoder.parameters(), lr = lr)

  training_pairs = [tensors_from_pair(random.choice(pairs)) 
                    for _ in range(epochs)]
  print(training_pairs)
  loss_func = nn.NLLLoss()

  for epoch in range(1, epochs + 1):
    print(f'======= {epoch} start ====')
    training_pair = training_pairs[epoch - 1]
    input_tensor = training_pair[0]
    label_tensor = training_pair[1]

    loss = train(input_tensor, label_tensor, encoder, decoder,
                 encoder_optim, decoder_optim, loss_func)
    
    if epoch % print_every == 0:
      print_loss_avg = print_loss_total / print_every
      print_loss_total = 0
      print(f'{time_since(start, epoch / epochs)} ({epoch} {epoch *100/ epochs}%) {print_loss_avg:.4f}')

    
    if epoch % plot_every == 0:
      plot_loss_avg = plot_loss_total / plot_every
      plot_losses.append(plot_loss_avg)
      plot_loss_total = 0

    show_plot(plot_losses)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.switch_backend('agg')

def show_plot(points):
  plt.figure()
  fig, ax = plt.subplots()

  loc = ticker.MultipleLocator(base=0.2)
  ax.yaxis.set_major_locator(loc)
  plt.plot(points)

# %%
hidden_size = 256
encoder1 = Encoder(dialect.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoder(hidden_size, standard.n_words, dropout_p=0.1).to(device)

train_iters(encoder1, attn_decoder1, 75000, print_every = 5000)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ======= 3 start ====
#
#
#
#  2
#
#
#
# ======= 4 start ====
#
#
#
#  2
#
#
#
# ======= 5 start ====
#
#
#
#  2
#
#
#
# ======= 6 start ====
#
#
#
#  2
#
#
#
# ======= 7 start ====
#
#
#
#  2
#
#
#
# ======= 8 start ====
#
#
#
#  2
#
#
#
# ======= 9 start ====
#
#
#
#  2
#
#
#
# ======= 10 start ====
#
#
#
#  2
#
#
#
# ======= 11 start ====
#
#
#
#  2
#
#
#
# ======= 12 start ====
#
#
#
#  2
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if __name__ == '__main__':
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ======= 4376 start ====
#
#
#
#  2
#
#
#
# ======= 4377 start ====
#
#
#
#  2
#
#
#
# ======= 4378 start ====
#
#
#
#  2
#
#
#
# ======= 4379 start ====
#
#
#
#  2
#
#
#
# ======= 4380 start ====
#
#
#
#  2
#
#
#
# ======= 4381 start ====
#
#
#
#  2
#
#
#
# ======= 4382 start ====
#
#
#
#  2
#
#
#
# ======= 4383 start ====
#
#
#
#  2
#
#
#
# ======= 4384 start ====
#
#
#
#  2
#
#
#
# ======= 4385 start ====
#
#
#
#  2
#
#
#
# ======= 4386 start ====
#
#
#
#  2
#
#
#
# ======= 4387 start ====
#
#
#
#  2
#
#
#
# ======= 4388 start ====
#
#
#
#  2
#
#
#
# ======= 4389 start ====
#
#
#
#  2
#
#
#
# ======= 4390 start ====
#
#
#
#  2
#
#
#
# ======= 4391 start ====
#
#
#
#  2
#
#
#
# ======= 4392 start ====
#
#
#
#  2
#
#
#
# ======= 4393 start ====
#
#
#
#  2
#
#
#
# ======= 4394 start ====
#
#
#
#  2
#
#
#
# ======= 4395 start ====
#
#
#
#  2
#
#
#
# ======= 4396 start ====
#
#
#
#  2
#
#
#
# ======= 4397 start ====
#
#
#
#  2
#
#
#
# ======= 4398 start ====
#
#
#
#  2
#
#
#
# ======= 4399 start ====
#
#
#
#  2
#
#
#
# ======= 4400 start ====
#
#
#
#  2
#
#
#
# ======= 4401 start ====
#
#
#
#  2
#
#
#
# ======= 4402 start ====
#
#
#
#  2
#
#
#
# ======= 4403 start ====
#
#
#
#  2
#
#
#
# ======= 4404 start ====
#
#
#
#  2
#
#
#
# ======= 4405 start ====
#
#
#
#  2
#
#
#
# ======= 4406 start ====
#
#
#
#  2
#
#
#
# ======= 4407 start ====
#
#
#
#  2
#
#
#
# ======= 4408 start ====
#
#
#
#  2
#
#
#
# ======= 4409 start ====
#
#
#
#  2
#
#
#
# ======= 4410 start ====
#
#
#
#  2
#
#
#
# ======= 4411 start ====
#
#
#
#  2
#
#
#
# ======= 4412 start ====
#
#
#
#  2
#
#
#
# ======= 4413 start ====
#
#
#
#  2
#
#
#
# ======= 4414 start ====
#
#
#
#  2
#
#
#
# ======= 4415 start ====
#
#
#
#  2
#
#
#
# ======= 4416 start ====
#
#
#
#  2
#
#
#
# ======= 4417 start ====
#
#
#
#  2
#
#
#
# ======= 4418 start ====
#
#
#
#  2
#
#
#
# ======= 4419 start ====
#
#
#
#  2
#
#
#
# ======= 4420 start ====
#
#
#
#  2
#
#
#
# ======= 4421 start ====
#
#
#
#  2
#
#
#
# ======= 4422 start ====
#
#
#
#  2
#
#
#
# ======= 4423 start ====
#
#
#
#  2
#
#
#
# ======= 4424 start ====
#
#
#
#  2
#
#
#
# ======= 4425 start ====
#
#
#
#  2
#
#
#
# ======= 4426 start ====
#
#
#
#  2
#
#
#
# ======= 4427 start ====
#
#
#
#  2
#
#
#
# ======= 4428 start ====
#
#
#
#  2
#
#
#
# ======= 4429 start ====
#
#
#
#  2
#
#
#
# ======= 4430 start ====
#
#
#
#  2
#
#
#
# ======= 4431 start ====
#
#
#
#  2
#
#
#
# ======= 4432 start ====
#
#
#
#  2
#
#
#
# ======= 4433 start ====
#
#
#
#  2
#
#
#
# ======= 4434 start ====
#
#
#
#  2
#
#
#
# ======= 4435 start ====
#
#
#
#  2
#
#
#
# ======= 4436 start ====
#
#
#
#  2
#
#
#
# ======= 4437 start ====
#
#
#
#  2
#
#
#
# ======= 4438 start ====
#
#
#
#  2
#
#
#
# ======= 4439 start ====
#
#
#
#  2
#
#
#
# ======= 4440 start ====
#
#
#
#  2
#
#
#
# ======= 4441 start ====
#
#
#
#  2
#
#
#
# ======= 4442 start ====
#
#
#
#  2
#
#
#
# ======= 4443 start ====
#
#
#
#  2
#
#
#
# ======= 4444 start ====
#
#
#
#  2
#
#
#
# ======= 4445 start ====
#
#
#
#  2
#
#
#
# ======= 4446 start ====
#
#
#
#  2
#
#
#
# ======= 4447 start ====
#
#
#
#  2
#
#
#
# ======= 4448 start ====
#
#
#
#  2
#
#
#
# ======= 4449 start ====
#
#
#
#  2
#
#
#
# ======= 4450 start ====
#
#
#
#  2
#
#
#
# ======= 4451 start ====
#
#
#
#  2
#
#
#
# ======= 4452 start ====
#
#
#
#  2
#
#
#
# ======= 4453 start ====
#
#
#
#  2
#
#
#
# ======= 4454 start ====
#
#
#
#  2
#
#
#
# ======= 4455 start ====
#
#
#
#  2
#
#
#
# ======= 4456 start ====
#
#
#
#  2
#
#
#
# ======= 4457 start ====
#
#
#
#  2
#
#
#
# ======= 4458 start ====
#
#
#
#  2
#
#
#
# ======= 4459 start ====
#
#
#
#  2
#
#
#
# ======= 4460 start ====
#
#
#
#  2
#
#
#
# ======= 4461 start ====
#
#
#
#  2
#
#
#
# ======= 4462 start ====
#
#
#
#  2
#
#
#
# ======= 4463 start ====
#
#
#
#  2
#
#
#
# ======= 4464 start ====
#
#
#
#  2
#
#
#
# ======= 4465 start ====
#
#
#
#  2
#
#
#
# ======= 4466 start ====
#
#
#
#  2
#
#
#
# ======= 4467 start ====
#
#
#
#  2
#
#
#
# ======= 4468 start ====
#
#
#
#  2
#
#
#
# ======= 4469 start ====
#
#
#
#  2
#
#
#
# ======= 4470 start ====
#
#
#
#  2
#
#
#
# ======= 4471 start ====
#
#
#
#  2
#
#
#
# ======= 4472 start ====
#
#
#
#  2
#
#
#
# ======= 4473 start ====
#
#
#
#  2
#
#
#
# ======= 4474 start ====
#
#
#
#  2
#
#
#
# ======= 4475 start ====
#
#
#
#  2
#
#
#
# ======= 4476 start ====
#
#
#
#  2
#
#
#
# ======= 4477 start ====
#
#
#
#  2
#
#
#
# ======= 4478 start ====
#
#
#
#  2
#
#
#
# ======= 4479 start ====
#
#
#
#  2
#
#
#
# ======= 4480 start ====
#
#
#
#  2
#
#
#
# ======= 4481 start ====
#
#
#
#  2
#
#
#
# ======= 4482 start ====
#
#
#
#  2
#
#
#
# ======= 4483 start ====
#
#
#
#  2
#
#
#
# ======= 4484 start ====
#
#
#
#  2
#
#
#
# ======= 4485 start ====
#
#
#
#  2
#
#
#
# ======= 4486 start ====
#
#
#
#  2
#
#
#
# ======= 4487 start ====
#
#
#
#  2
#
#
#
# ======= 4488 start ====
#
#
#
#  2
#
#
#
# ======= 4489 start ====
#
#
#
#  2
#
#
#
# ======= 4490 start ====
#
#
#
#  2
#
#
#
# ======= 4491 start ====
#
#
#
#  2
#
#
#
# ======= 4492 start ====
#
#
#
#  2
#
#
#
# ======= 4493 start ====
#
#
#
#  2
#
#
#
# ======= 4494 start ====
#
#
#
#  2
#
#
#
# ======= 4495 start ====
#
#
#
#  2
#
#
#
# ======= 4496 start ====
#
#
#
#  2
#
#
#
# ======= 4497 start ====
#
#
#
#  2
#
#
#
# ======= 4498 start ====
#
#
#
#  2
#
#
#
# ======= 4499 start ====
#
#
#
#  2
#
#
#
# ======= 4500 start ====
#
#
#
#  2
#
#
#
# ======= 4501 start ====
#
#
#
#  2
#
#
#
# ======= 4502 start ====
#
#
#
#  2
#
#
#
# ======= 4503 start ====
#
#
#
#  2
#
#
#
# ======= 4504 start ====
#
#
#
#  2
#
#
#
# ======= 4505 start ====
#
#
#
#  2
#
#
#
# ======= 4506 start ====
#
#
#
#  2
#
#
#
# ======= 4507 start ====
#
#
#
#  2
#
#
#
# ======= 4508 start ====
#
#
#
#  2
#
#
#
# ======= 4509 start ====
#
#
#
#  2
#
#
#
# ======= 4510 start ====
#
#
#
#  2
#
#
#
# ======= 4511 start ====
#
#
#
#  2
#
#
#
# ======= 4512 start ====
#
#
#
#  2
#
#
#
# ======= 4513 start ====
#
#
#
#  2
#
#
#
# ======= 4514 start ====
#
#
#
#  2
#
#
#
# ======= 4515 start ====
#
#
#
#  2
#
#
#
# ======= 4516 start ====
#
#
#
#  2
#
#
#
# ======= 4517 start ====
#
#
#
#  2
#
#
#
# ======= 4518 start ====
#
#
#
#  2
#
#
#
# ======= 4519 start ====
#
#
#
#  2
#
#
#
# ======= 4520 start ====
#
#
#
#  2
#
#
#
# ======= 4521 start ====
#
#
#
#  2
#
#
#
# ======= 4522 start ====
#
#
#
#  2
#
#
#
# ======= 4523 start ====
#
#
#
#  2
#
#
#
# ======= 4524 start ====
#
#
#
#  2
#
#
#
# ======= 4525 start ====
#
#
#
#  2
#
#
#
# ======= 4526 start ====
#
#
#
#  2
#
#
#
# ======= 4527 start ====
#
#
#
#  2
#
#
#
# ======= 4528 start ====
#
#
#
#  2
#
#
#
# ======= 4529 start ====
#
#
#
#  2
#
#
#
# ======= 4530 start ====
#
#
#
#  2
#
#
#
# ======= 4531 start ====
#
#
#
#  2
#
#
#
# ======= 4532 start ====
#
#
#
#  2
#
#
#
# ======= 4533 start ====
#
#
#
#  2
#
#
#
# ======= 4534 start ====
#
#
#
#  2
#
#
#
# ======= 4535 start ====
#
#
#
#  2
#
#
#
# ======= 4536 start ====
#
#
#
#  2
#
#
#
# ======= 4537 start ====
#
#
#
#  2
#
#
#
# ======= 4538 start ====
#
#
#
#  2
#
#
#
# ======= 4539 start ====
#
#
#
#  2
#
#
#
# ======= 4540 start ====
#
#
#
#  2
#
#
#
# ======= 4541 start ====
#
#
#
#  2
#
#
#
# ======= 4542 start ====
#
#
#
#  2
#
#
#
# ======= 4543 start ====
#
#
#
#  2
#
#
#
# ======= 4544 start ====
#
#
#
#  2
#
#
#
# ======= 4545 start ====
#
#
#
#  2
#
#
#
# ======= 4546 start ====
#
#
#
#  2
#
#
#
# ======= 4547 start ====
#
#
#
#  2
#
#
#
# ======= 4548 start ====
#
#
#
#  2
#
#
#
# ======= 4549 start ====
#
#
#
#  2
#
#
#
# ======= 4550 start ====
#
#
#
#  2
#
#
#
# ======= 4551 start ====
#
#
#
#  2
#
#
#
# ======= 4552 start ====
#
#
#
#  2
#
#
#
# ======= 4553 start ====
#
#
#
#  2
#
#
#
# ======= 4554 start ====
#
#
#
#  2
#
#
#
# ======= 4555 start ====
#
#
#
#  2
#
#
#
# ======= 4556 start ====
#
#
#
#  2
#
#
#
# ======= 4557 start ====
#
#
#
#  2
#
#
#
# ======= 4558 start ====
#
#
#
#  2
#
#
#
# ======= 4559 start ====
#
#
#
#  2
#
#
#
# ======= 4560 start ====
#
#
#
#  2
#
#
#
# ======= 4561 start ====
#
#
#
#  2
#
#
#
# ======= 4562 start ====
#
#
#
#  2
#
#
#
# ======= 4563 start ====
#
#
#
#  2
#
#
#
# ======= 4564 start ====
#
#
#
#  2
#
#
#
# ======= 4565 start ====
#
#
#
#  2
#
#
#
# ======= 4566 start ====
#
#
#
#  2
#
#
#
# ======= 4567 start ====
#
#
#
#  2
#
#
#
# ======= 4568 start ====
#
#
#
#  2
#
#
#
# ======= 4569 start ====
#
#
#
#  2
#
#
#
# ======= 4570 start ====
#
#
#
#  2
#
#
#
# ======= 4571 start ====
#
#
#
#  2
#
#
#
# ======= 4572 start ====
#
#
#
#  2
#
#
#
# ======= 4573 start ====
#
#
#
#  2
#
#
#
# ======= 4574 start ====
#
#
#
#  2
#
#
#
# ======= 4575 start ====
#
#
#
#  2
#
#
#
# ======= 4576 start ====
#
#
#
#  2
#
#
#
# ======= 4577 start ====
#
#
#
#  2
#
#
#
# ======= 4578 start ====
#
#
#
#  2
#
#
#
# ======= 4579 start ====
#
#
#
#  2
#
#
#
# ======= 4580 start ====
#
#
#
#  2
#
#
#
# ======= 4581 start ====
#
#
#
#  2
#
#
#
# ======= 4582 start ====
#
#
#
#  2
#
#
#
# ======= 4583 start ====
#
#
#
#  2
#
#
#
# ======= 4584 start ====
#
#
#
#  2
#
#
#
# ======= 4585 start ====
#
#
#
#  2
#
#
#
# ======= 4586 start ====
#
#
#
#  2
#
#
#
# ======= 4587 start ====
#
#
#
#  2
#
#
#
# ======= 4588 start ====
#
#
#
#  2
#
#
#
# ======= 4589 start ====
#
#
#
#  2
#
#
#
# ======= 4590 start ====
#
#
#
#  2
#
#
#
# ======= 4591 start ====
#
#
#
#  2
#
#
#
# ======= 4592 start ====
#
#
#
#  2
#
#
#
# ======= 4593 start ====
#
#
#
#  2
#
#
#
# ======= 4594 start ====
#
#
#
#  2
#
#
#
# ======= 4595 start ====
#
#
#
#  2
#
#
#
# ======= 4596 start ====
#
#
#
#  2
#
#
#
# ======= 4597 start ====
#
#
#
#  2
#
#
#
# ======= 4598 start ====
#
#
#
#  2
#
#
#
# ======= 4599 start ====
#
#
#
#  2
#
#
#
# ======= 4600 start ====
#
#
#
#  2
#
#
#
# ======= 4601 start ====
#
#
#
#  2
#
#
#
# ======= 4602 start ====
#
#
#
#  2
#
#
#
# ======= 4603 start ====
#
#
#
#  2
#
#
#
# ======= 4604 start ====
#
#
#
#  2
#
#
#
# ======= 4605 start ====
#
#
#
#  2
#
#
#
# ======= 4606 start ====
#
#
#
#  2
#
#
#
# ======= 4607 start ====
#
#
#
#  2
#
#
#
# ======= 4608 start ====
#
#
#
#  2
#
#
#
# ======= 4609 start ====
#
#
#
#  2
#
#
#
# ======= 4610 start ====
#
#
#
#  2
#
#
#
# ======= 4611 start ====
#
#
#
#  2
#
#
#
# ======= 4612 start ====
#
#
#
#  2
#
#
#
# ======= 4613 start ====
#
#
#
#  2
#
#
#
# ======= 4614 start ====
#
#
#
#  2
#
#
#
# ======= 4615 start ====
#
#
#
#  2
#
#
#
# ======= 4616 start ====
#
#
#
#  2
#
#
#
# ======= 4617 start ====
#
#
#
#  2
#
#
#
# ======= 4618 start ====
#
#
#
#  2
#
#
#
# ======= 4619 start ====
#
#
#
#  2
#
#
#
# ======= 4620 start ====
#
#
#
#  2
#
#
#
# ======= 4621 start ====
#
#
#
#  2
#
#
#
# ======= 4622 start ====
#
#
#
#  2
#
#
#
# ======= 4623 start ====
#
#
#
#  2
#
#
#
# ======= 4624 start ====
#
#
#
#  2
#
#
#
# ======= 4625 start ====
#
#
#
#  2
#
#
#
# ======= 4626 start ====
#
#
#
#  2
#
#
#
# ======= 4627 start ====
#
#
#
#  2
#
#
#
# ======= 4628 start ====
#
#
#
#  2
#
#
#
# ======= 4629 start ====
#
#
#
#  2
#
#
#
# ======= 4630 start ====
#
#
#
#  2
#
#
#
# ======= 4631 start ====
#
#
#
#  2
#
#
#
# ======= 4632 start ====
#
#
#
#  2
#
#
#
# ======= 4633 start ====
#
#
#
#  2
#
#
#
# ======= 4634 start ====
#
#
#
#  2
#
#
#
# ======= 4635 start ====
#
#
#
#  2
#
#
#
# ======= 4636 start ====
#
#
#
#  2
#
#
#
# ======= 4637 start ====
#
#
#
#  2
#
#
#
# ======= 4638 start ====
#
#
#
#  2
#
#
#
# ======= 4639 start ====
#
#
#
#  2
#
#
#
# ======= 4640 start ====
#
#
#
#  2
#
#
#
# ======= 4641 start ====
#
#
#
#  2
#
#
#
# ======= 4642 start ====
#
#
#
#  2
#
#
#
# ======= 4643 start ====
#
#
#
#  2
#
#
#
# ======= 4644 start ====
#
#
#
#  2
#
#
#
# ======= 4645 start ====
#
#
#
#  2
#
#
#
# ======= 4646 start ====
#
#
#
#  2
#
#
#
# ======= 4647 start ====
#
#
#
#  2
#
#
#
# ======= 4648 start ====
#
#
#
#  2
#
#
#
# ======= 4649 start ====
#
#
#
#  2
#
#
#
# ======= 4650 start ====
#
#
#
#  2
#
#
#
# ======= 4651 start ====
#
#
#
#  2
#
#
#
# ======= 4652 start ====
#
#
#
#  2
#
#
#
# ======= 4653 start ====
#
#
#
#  2
#
#
#
# ======= 4654 start ====
#
#
#
#  2
#
#
#
# ======= 4655 start ====
#
#
#
#  2
#
#
#
# ======= 4656 start ====
#
#
#
#  2
#
#
#
# ======= 4657 start ====
#
#
#
#  2
#
#
#
# ======= 4658 start ====
#
#
#
#  2
#
#
#
# ======= 4659 start ====
#
#
#
#  2
#
#
#
# ======= 4660 start ====
#
#
#
#  2
#
#
#
# ======= 4661 start ====
#
#
#
#  2
#
#
#
# ======= 4662 start ====
#
#
#
#  2
#
#
#
# ======= 4663 start ====
#
#
#
#  2
#
#
#
# ======= 4664 start ====
#
#
#
#  2
#
#
#
# ======= 4665 start ====
#
#
#
#  2
#
#
#
# ======= 4666 start ====
#
#
#
#  2
#
#
#
# ======= 4667 start ====
#
#
#
#  2
#
#
#
# ======= 4668 start ====
#
#
#
#  2
#
#
#
# ======= 4669 start ====
#
#
#
#  2
#
#
#
# ======= 4670 start ====
#
#
#
#  2
#
#
#
# ======= 4671 start ====
#
#
#
#  2
#
#
#
# ======= 4672 start ====
#
#
#
#  2
#
#
#
# ======= 4673 start ====
#
#
#
#  2
#
#
#
# ======= 4674 start ====
#
#
#
#  2
#
#
#
# ======= 4675 start ====
#
#
#
#  2
#
#
#
# ======= 4676 start ====
#
#
#
#  2
#
#
#
# ======= 4677 start ====
#
#
#
#  2
#
#
#
# ======= 4678 start ====
#
#
#
#  2
#
#
#
# ======= 4679 start ====
#
#
#
#  2
#
#
#
# ======= 4680 start ====
#
#
#
#  2
#
#
#
# ======= 4681 start ====
#
#
#
#  2
#
#
#
# ======= 4682 start ====
#
#
#
#  2
#
#
#
# ======= 4683 start ====
#
#
#
#  2
#
#
#
# ======= 4684 start ====
#
#
#
#  2
#
#
#
# ======= 4685 start ====
#
#
#
#  2
#
#
#
# ======= 4686 start ====
#
#
#
#  2
#
#
#
# ======= 4687 start ====
#
#
#
#  2
#
#
#
# ======= 4688 start ====
#
#
#
#  2
#
#
#
# ======= 4689 start ====
#
#
#
#  2
#
#
#
# ======= 4690 start ====
#
#
#
#  2
#
#
#
# ======= 4691 start ====
#
#
#
#  2
#
#
#
# ======= 4692 start ====
#
#
#
#  2
#
#
#
# ======= 4693 start ====
#
#
#
#  2
#
#
#
# ======= 4694 start ====
#
#
#
#  2
#
#
#
# ======= 4695 start ====
#
#
#
#  2
#
#
#
# ======= 4696 start ====
#
#
#
#  2
#
#
#
# ======= 4697 start ====
#
#
#
#  2
#
#
#
# ======= 4698 start ====
#
#
#
#  2
#
#
#
# ======= 4699 start ====
#
#
#
#  2
#
#
#
# ======= 4700 start ====
#
#
#
#  2
#
#
#
# ======= 4701 start ====
#
#
#
#  2
#
#
#
# ======= 4702 start ====
#
#
#
#  2
#
#
#
# ======= 4703 start ====
#
#
#
#  2
#
#
#
# ======= 4704 start ====
#
#
#
#  2
#
#
#
# ======= 4705 start ====
#
#
#
#  2
#
#
#
# ======= 4706 start ====
#
#
#
#  2
#
#
#
# ======= 4707 start ====
#
#
#
#  2
#
#
#
# ======= 4708 start ====
#
#
#
#  2
#
#
#
# ======= 4709 start ====
#
#
#
#  2
#
#
#
# ======= 4710 start ====
#
#
#
#  2
#
#
#
# ======= 4711 start ====
#
#
#
#  2
#
#
#
# ======= 4712 start ====
#
#
#
#  2
#
#
#
# ======= 4713 start ====
#
#
#
#  2
#
#
#
# ======= 4714 start ====
#
#
#
#  2
#
#
#
# ======= 4715 start ====
#
#
#
#  2
#
#
#
# ======= 4716 start ====
#
#
#
#  2
#
#
#
# ======= 4717 start ====
#
#
#
#  2
#
#
#
# ======= 4718 start ====
#
#
#
#  2
#
#
#
# ======= 4719 start ====
#
#
#
#  2
#
#
#
# ======= 4720 start ====
#
#
#
#  2
#
#
#
# ======= 4721 start ====
#
#
#
#  2
#
#
#
# ======= 4722 start ====
#
#
#
#  2
#
#
#
# ======= 4723 start ====
#
#
#
#  2
#
#
#
# ======= 4724 start ====
#
#
#
#  2
#
#
#
# ======= 4725 start ====
#
#
#
#  2
#
#
#
# ======= 4726 start ====
#
#
#
#  2
#
#
#
# ======= 4727 start ====
#
#
#
#  2
#
#
#
# ======= 4728 start ====
#
#
#
#  2
#
#
#
# ======= 4729 start ====
#
#
#
#  2
#
#
#
# ======= 4730 start ====
#
#
#
#  2
#
#
#
# ======= 4731 start ====
#
#
#
#  2
#
#
#
# ======= 4732 start ====
#
#
#
#  2
#
#
#
# ======= 4733 start ====
#
#
#
#  2
#
#
#
# ======= 4734 start ====
#
#
#
#  2
#
#
#
# ======= 4735 start ====
#
#
#
#  2
#
#
#
# ======= 4736 start ====
#
#
#
#  2
#
#
#
# ======= 4737 start ====
#
#
#
#  2
#
#
#
# ======= 4738 start ====
#
#
#
#  2
#
#
#
# ======= 4739 start ====
#
#
#
#  2
#
#
#
# ======= 4740 start ====
#
#
#
#  2
#
#
#
# ======= 4741 start ====
#
#
#
#  2
#
#
#
# ======= 4742 start ====
#
#
#
#  2
#
#
#
# ======= 4743 start ====
#
#
#
#  2
#
#
#
# ======= 4744 start ====
#
#
#
#  2
#
#
#
# ======= 4745 start ====
#
#
#
#  2
#
#
#
# ======= 4746 start ====
#
#
#
#  2
#
#
#
# ======= 4747 start ====
#
#
#
#  2
#
#
#
# ======= 4748 start ====
#
#
#
#  2
#
#
#
# ======= 4749 start ====
#
#
#
#  2
#
#
#
# ======= 4750 start ====
#
#
#
#  2
#
#
#
# ======= 4751 start ====
#
#
#
#  2
#
#
#
# ======= 4752 start ====
#
#
#
#  2
#
#
#
# ======= 4753 start ====
#
#
#
#  2
#
#
#
# ======= 4754 start ====
#
#
#
#  2
#
#
#
# ======= 4755 start ====
#
#
#
#  2
#
#
#
# ======= 4756 start ====
#
#
#
#  2
#
#
#
# ======= 4757 start ====
#
#
#
#  2
#
#
#
# ======= 4758 start ====
#
#
#
#  2
#
#
#
# ======= 4759 start ====
#
#
#
#  2
#
#
#
# ======= 4760 start ====
#
#
#
#  2
#
#
#
# ======= 4761 start ====
#
#
#
#  2
#
#
#
# ======= 4762 start ====
#
#
#
#  2
#
#
#
# ======= 4763 start ====
#
#
#
#  2
#
#
#
# ======= 4764 start ====
#
#
#
#  2
#
#
#
# ======= 4765 start ====
#
#
#
#  2
#
#
#
# ======= 4766 start ====
#
#
#
#  2
#
#
#
# ======= 4767 start ====
#
#
#
#  2
#
#
#
# ======= 4768 start ====
#
#
#
#  2
#
#
#
# ======= 4769 start ====
#
#
#
#  2
#
#
#
# ======= 4770 start ====
#
#
#
#  2
#
#
#
# ======= 4771 start ====
#
#
#
#  2
#
#
#
# ======= 4772 start ====
#
#
#
#  2
#
#
#
# ======= 4773 start ====
#
#
#
#  2
#
#
#
# ======= 4774 start ====
#
#
#
#  2
#
#
#
# ======= 4775 start ====
#
#
#
#  2
#
#
#
# ======= 4776 start ====
#
#
#
#  2
#
#
#
# ======= 4777 start ====
#
#
#
#  2
#
#
#
# ======= 4778 start ====
#
#
#
#  2
#
#
#
# ======= 4779 start ====
#
#
#
#  2
#
#
#
# ======= 4780 start ====
#
#
#
#  2
#
#
#
# ======= 4781 start ====
#
#
#
#  2
#
#
#
# ======= 4782 start ====
#
#
#
#  2
#
#
#
# ======= 4783 start ====
#
#
#
#  2
#
#
#
# ======= 4784 start ====
#
#
#
#  2
#
#
#
# ======= 4785 start ====
#
#
#
#  2
#
#
#
# ======= 4786 start ====
#
#
#
#  2
#
#
#
# ======= 4787 start ====
#
#
#
#  2
#
#
#
# ======= 4788 start ====
#
#
#
#  2
#
#
#
# ======= 4789 start ====
#
#
#
#  2
#
#
#
# ======= 4790 start ====
#
#
#
#  2
#
#
#
# ======= 4791 start ====
#
#
#
#  2
#
#
#
# ======= 4792 start ====
#
#
#
#  2
#
#
#
# ======= 4793 start ====
#
#
#
#  2
#
#
#
# ======= 4794 start ====
#
#
#
#  2
#
#
#
# ======= 4795 start ====
#
#
#
#  2
#
#
#
# ======= 4796 start ====
#
#
#
#  2
#
#
#
# ======= 4797 start ====
#
#
#
#  2
#
#
#
# ======= 4798 start ====
#
#
#
#  2
#
#
#
# ======= 4799 start ====
#
#
#
#  2
#
#
#
# ======= 4800 start ====
#
#
#
#  2
#
#
#
# ======= 4801 start ====
#
#
#
#  2
#
#
#
# ======= 4802 start ====
#
#
#
#  2
#
#
#
# ======= 4803 start ====
#
#
#
#  2
#
#
#
# ======= 4804 start ====
#
#
#
#  2
#
#
#
# ======= 4805 start ====
#
#
#
#  2
#
#
#
# ======= 4806 start ====
#
#
#
#  2
#
#
#
# ======= 4807 start ====
#
#
#
#  2
#
#
#
# ======= 4808 start ====
#
#
#
#  2
#
#
#
# ======= 4809 start ====
#
#
#
#  2
#
#
#
# ======= 4810 start ====
#
#
#
#  2
#
#
#
# ======= 4811 start ====
#
#
#
#  2
#
#
#
# ======= 4812 start ====
#
#
#
#  2
#
#
#
# ======= 4813 start ====
#
#
#
#  2
#
#
#
# ======= 4814 start ====
#
#
#
#  2
#
#
#
# ======= 4815 start ====
#
#
#
#  2
#
#
#
# ======= 4816 start ====
#
#
#
#  2
#
#
#
# ======= 4817 start ====
#
#
#
#  2
#
#
#
# ======= 4818 start ====
#
#
#
#  2
#
#
#
# ======= 4819 start ====
#
#
#
#  2
#
#
#
# ======= 4820 start ====
#
#
#
#  2
#
#
#
# ======= 4821 start ====
#
#
#
#  2
#
#
#
# ======= 4822 start ====
#
#
#
#  2
#
#
#
# ======= 4823 start ====
#
#
#
#  2
#
#
#
# ======= 4824 start ====
#
#
#
#  2
#
#
#
# ======= 4825 start ====
#
#
#
#  2
#
#
#
# ======= 4826 start ====
#
#
#
#  2
#
#
#
# ======= 4827 start ====
#
#
#
#  2
#
#
#
# ======= 4828 start ====
#
#
#
#  2
#
#
#
# ======= 4829 start ====
#
#
#
#  2
#
#
#
# ======= 4830 start ====
#
#
#
#  2
#
#
#
# ======= 4831 start ====
#
#
#
#  2
#
#
#
# ======= 4832 start ====
#
#
#
#  2
#
#
#
# ======= 4833 start ====
#
#
#
#  2
#
#
#
# ======= 4834 start ====
#
#
#
#  2
#
#
#
# ======= 4835 start ====
#
#
#
#  2
#
#
#
# ======= 4836 start ====
#
#
#
#  2
#
#
#
# ======= 4837 start ====
#
#
#
#  2
#
#
#
# ======= 4838 start ====
#
#
#
#  2
#
#
#
# ======= 4839 start ====
#
#
#
#  2
#
#
#
# ======= 4840 start ====
#
#
#
#  2
#
#
#
# ======= 4841 start ====
#
#
#
#  2
#
#
#
# ======= 4842 start ====
#
#
#
#  2
#
#
#
# ======= 4843 start ====
#
#
#
#  2
#
#
#
# ======= 4844 start ====
#
#
#
#  2
#
#
#
# ======= 4845 start ====
#
#
#
#  2
#
#
#
# ======= 4846 start ====
#
#
#
#  2
#
#
#
# ======= 4847 start ====
#
#
#
#  2
#
#
#
# ======= 4848 start ====
#
#
#
#  2
#
#
#
# ======= 4849 start ====
#
#
#
#  2
#
#
#
# ======= 4850 start ====
#
#
#
#  2
#
#
#
# ======= 4851 start ====
#
#
#
#  2
#
#
#
# ======= 4852 start ====
#
#
#
#  2
#
#
#
# ======= 4853 start ====
#
#
#
#  2
#
#
#
# ======= 4854 start ====
#
#
#
#  2
#
#
#
# ======= 4855 start ====
#
#
#
#  2
#
#
#
# ======= 4856 start ====
#
#
#
#  2
#
#
#
# ======= 4857 start ====
#
#
#
#  2
#
#
#
# ======= 4858 start ====
#
#
#
#  2
#
#
#
# ======= 4859 start ====
#
#
#
#  2
#
#
#
# ======= 4860 start ====
#
#
#
#  2
#
#
#
# ======= 4861 start ====
#
#
#
#  2
#
#
#
# ======= 4862 start ====
#
#
#
#  2
#
#
#
# ======= 4863 start ====
#
#
#
#  2
#
#
#
# ======= 4864 start ====
#
#
#
#  2
#
#
#
# ======= 4865 start ====
#
#
#
#  2
#
#
#
# ======= 4866 start ====
#
#
#
#  2
#
#
#
# ======= 4867 start ====
#
#
#
#  2
#
#
#
# ======= 4868 start ====
#
#
#
#  2
#
#
#
# ======= 4869 start ====
#
#
#
#  2
#
#
#
# ======= 4870 start ====
#
#
#
#  2
#
#
#
# ======= 4871 start ====
#
#
#
#  2
#
#
#
# ======= 4872 start ====
#
#
#
#  2
#
#
#
# ======= 4873 start ====
#
#
#
#  2
#
#
#
# ======= 4874 start ====
#
#
#
#  2
#
#
#
# ======= 4875 start ====
#
#
#
#  2
#
#
#
# ======= 4876 start ====
#
#
#
#  2
#
#
#
# ======= 4877 start ====
#
#
#
#  2
#
#
#
# ======= 4878 start ====
#
#
#
#  2
#
#
#
# ======= 4879 start ====
#
#
#
#  2
#
#
#
# ======= 4880 start ====
#
#
#
#  2
#
#
#
# ======= 4881 start ====
#
#
#
#  2
#
#
#
# ======= 4882 start ====
#
#
#
#  2
#
#
#
# ======= 4883 start ====
#
#
#
#  2
#
#
#
# ======= 4884 start ====
#
#
#
#  2
#
#
#
# ======= 4885 start ====
#
#
#
#  2
#
#
#
# ======= 4886 start ====
#
#
#
#  2
#
#
#
# ======= 4887 start ====
#
#
#
#  2
#
#
#
# ======= 4888 start ====
#
#
#
#  2
#
#
#
# ======= 4889 start ====
#
#
#
#  2
#
#
#
# ======= 4890 start ====
#
#
#
#  2
#
#
#
# ======= 4891 start ====
#
#
#
#  2
#
#
#
# ======= 4892 start ====
#
#
#
#  2
#
#
#
# ======= 4893 start ====
#
#
#
#  2
#
#
#
# ======= 4894 start ====
#
#
#
#  2
#
#
#
# ======= 4895 start ====
#
#
#
#  2
#
#
#
# ======= 4896 start ====
#
#
#
#  2
#
#
#
# ======= 4897 start ====
#
#
#
#  2
#
#
#
# ======= 4898 start ====
#
#
#
#  2
#
#
#
# ======= 4899 start ====
#
#
#
#  2
#
#
#
# ======= 4900 start ====
#
#
#
#  2
#
#
#
# ======= 4901 start ====
#
#
#
#  2
#
#
#
# ======= 4902 start ====
#
#
#
#  2
#
#
#
# ======= 4903 start ====
#
#
#
#  2
#
#
#
# ======= 4904 start ====
#
#
#
#  2
#
#
#
# ======= 4905 start ====
#
#
#
#  2
#
#
#
# ======= 4906 start ====
#
#
#
#  2
#
#
#
# ======= 4907 start ====
#
#
#
#  2
#
#
#
# ======= 4908 start ====
#
#
#
#  2
#
#
#
# ======= 4909 start ====
#
#
#
#  2
#
#
#
# ======= 4910 start ====
#
#
#
#  2
#
#
#
# ======= 4911 start ====
#
#
#
#  2
#
#
#
# ======= 4912 start ====
#
#
#
#  2
#
#
#
# ======= 4913 start ====
#
#
#
#  2
#
#
#
# ======= 4914 start ====
#
#
#
#  2
#
#
#
# ======= 4915 start ====
#
#
#
#  2
#
#
#
# ======= 4916 start ====
#
#
#
#  2
#
#
#
# ======= 4917 start ====
#
#
#
#  2
#
#
#
# ======= 4918 start ====
#
#
#
#  2
#
#
#
# ======= 4919 start ====
#
#
#
#  2
#
#
#
# ======= 4920 start ====
#
#
#
#  2
#
#
#
# ======= 4921 start ====
#
#
#
#  2
#
#
#
# ======= 4922 start ====
#
#
#
#  2
#
#
#
# ======= 4923 start ====
#
#
#
#  2
#
#
#
# ======= 4924 start ====
#
#
#
#  2
#
#
#
# ======= 4925 start ====
#
#
#
#  2
#
#
#
# ======= 4926 start ====
#
#
#
#  2
#
#
#
# ======= 4927 start ====
#
#
#
#  2
#
#
#
# ======= 4928 start ====
#
#
#
#  2
#
#
#
# ======= 4929 start ====
#
#
#
#  2
#
#
#
# ======= 4930 start ====
#
#
#
#  2
#
#
#
# ======= 4931 start ====
#
#
#
#  2
#
#
#
# ======= 4932 start ====
#
#
#
#  2
#
#
#
# ======= 4933 start ====
#
#
#
#  2
#
#
#
# ======= 4934 start ====
#
#
#
#  2
#
#
#
# ======= 4935 start ====
#
#
#
#  2
#
#
#
# ======= 4936 start ====
#
#
#
#  2
#
#
#
# ======= 4937 start ====
#
#
#
#  2
#
#
#
# ======= 4938 start ====
#
#
#
#  2
#
#
#
# ======= 4939 start ====
#
#
#
#  2
#
#
#
# ======= 4940 start ====
#
#
#
#  2
#
#
#
# ======= 4941 start ====
#
#
#
#  2
#
#
#
# ======= 4942 start ====
#
#
#
#  2
#
#
#
# ======= 4943 start ====
#
#
#
#  2
#
#
#
# ======= 4944 start ====
#
#
#
#  2
#
#
#
# ======= 4945 start ====
#
#
#
#  2
#
#
#
# ======= 4946 start ====
#
#
#
#  2
#
#
#
# ======= 4947 start ====
#
#
#
#  2
#
#
#
# ======= 4948 start ====
#
#
#
#  2
#
#
#
# ======= 4949 start ====
#
#
#
#  2
#
#
#
# ======= 4950 start ====
#
#
#
#  2
#
#
#
# ======= 4951 start ====
#
#
#
#  2
#
#
#
# ======= 4952 start ====
#
#
#
#  2
#
#
#
# ======= 4953 start ====
#
#
#
#  2
#
#
#
# ======= 4954 start ====
#
#
#
#  2
#
#
#
# ======= 4955 start ====
#
#
#
#  2
#
#
#
# ======= 4956 start ====
#
#
#
#  2
#
#
#
# ======= 4957 start ====
#
#
#
#  2
#
#
#
# ======= 4958 start ====
#
#
#
#  2
#
#
#
# ======= 4959 start ====
#
#
#
#  2
#
#
#
# ======= 4960 start ====
#
#
#
#  2
#
#
#
# ======= 4961 start ====
#
#
#
#  2
#
#
#
# ======= 4962 start ====
#
#
#
#  2
#
#
#
# ======= 4963 start ====
#
#
#
#  2
#
#
#
# ======= 4964 start ====
#
#
#
#  2
#
#
#
# ======= 4965 start ====
#
#
#
#  2
#
#
#
# ======= 4966 start ====
#
#
#
#  2
#
#
#
# ======= 4967 start ====
#
#
#
#  2
#
#
#
# ======= 4968 start ====
#
#
#
#  2
#
#
#
# ======= 4969 start ====
#
#
#
#  2
#
#
#
# ======= 4970 start ====
#
#
#
#  2
#
#
#
# ======= 4971 start ====
#
#
#
#  2
#
#
#
# ======= 4972 start ====
#
#
#
#  2
#
#
#
# ======= 4973 start ====
#
#
#
#  2
#
#
#
# ======= 4974 start ====
#
#
#
#  2
#
#
#
# ======= 4975 start ====
#
#
#
#  2
#
#
#
# ======= 4976 start ====
#
#
#
#  2
#
#
#
# ======= 4977 start ====
#
#
#
#  2
#
#
#
# ======= 4978 start ====
#
#
#
#  2
#
#
#
# ======= 4979 start ====
#
#
#
#  2
#
#
#
# ======= 4980 start ====
#
#
#
#  2
#
#
#
# ======= 4981 start ====
#
#
#
#  2
#
#
#
# ======= 4982 start ====
#
#
#
#  2
#
#
#
# ======= 4983 start ====
#
#
#
#  2
#
#
#
# ======= 4984 start ====
#
#
#
#  2
#
#
#
# ======= 4985 start ====
#
#
#
#  2
#
#
#
# ======= 4986 start ====
#
#
#
#  2
#
#
#
# ======= 4987 start ====
#
#
#
#  2
#
#
#
# ======= 4988 start ====
#
#
#
#  2
#
#
#
# ======= 4989 start ====
#
#
#
#  2
#
#
#
# ======= 4990 start ====
#
#
#
#  2
#
#
#
# ======= 4991 start ====
#
#
#
#  2
#
#
#
# ======= 4992 start ====
#
#
#
#  2
#
#
#
# ======= 4993 start ====
#
#
#
#  2
#
#
#
# ======= 4994 start ====
#
#
#
#  2
#
#
#
# ======= 4995 start ====
#
#
#
#  2
#
#
#
# ======= 4996 start ====
#
#
#
#  2
#
#
#
# ======= 4997 start ====
#
#
#
#  2
#
#
#
# ======= 4998 start ====
#
#
#
#  2
#
#
#
# ======= 4999 start ====
#
#
#
#  2
#
#
#
# ======= 5000 start ====
#
#
#
#  2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-d4c52b13ff73> in <module>()
#       3 attn_decoder1 = AttnDecoder(hidden_size, standard.n_words, dropout_p=0.1).to(device)
#       4
# ----> 5 train_iters(encoder1, attn_decoder1, 75000, print_every = 5000)
#
# <ipython-input-76-5b8d901a4d43> in train_iters(encoder, decoder, epochs, lr, print_every, plot_every)
#      26       print_loss_avg = print_loss_total / print_every
#      27       print_loss_total = 0
# ---> 28       print(f'{time_since(start, epoch / epochs)} ({epoch} {epoch *100/ epochs}%) {print_loss_avg:.4f}')
#      29
#      30
#
# <ipython-input-75-3a01531d2b6f> in time_since(since, percent)
#      11   es = spend / percent
#      12   rs = es - spend
# ---> 13   return f'{as_minutes(spend)} (- {as_minutes(rs)})'
#
# <ipython-input-75-3a01531d2b6f> in as_minutes(seconds)
#       2
#       3 def as_minutes(seconds):
# ----> 4   minute = math.floor(secods / 60)
#       5   seconds -= minute * 60
#       6   return f'{minute}min {seconds}sec'
#
# NameError: name 'secods' is not defined
