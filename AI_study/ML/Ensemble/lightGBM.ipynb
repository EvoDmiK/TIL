# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
from lightgbm import plot_importance
from lightgbm import LGBMClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import *
import pandas as pd
import numpy as np

# %%
def get_clf_eval(gt, pred = None, pred_proba = None):
    
    conf_mat  = confusion_matrix(gt, pred)
    accuracy  = accuracy_score(gt, pred)
    precision = precision_score(gt, pred)
    recall    = recall_score(gt, pred)
    F1        = f1_score(gt, pred)
    AUC       = roc_auc_score(gt, pred)
    
    print(f'confusion matrix \n{conf_mat}\n')
    print(f'accuracy  : {accuracy:.3f}')
    print(f'precision : {precision:.3f}')
    print(f'recall    : {recall:.3f}')
    print(f'F1 score  : {F1:.3f}')
    print(f'AUC score : {AUC:.3f}')

# %%
dataset = load_breast_cancer()
feats   = dataset.data
target  = dataset.target

train_x, test_x, train_y, test_y = train_test_split(feats, target, test_size = 0.2, random_state = 99,
                                                    shuffle = True, stratify = target)

lgbm_wrapper = LGBMClassifier(n_estimators = 400)
evals        = [(test_x, test_y)]
lgbm_wrapper.fit(train_x, train_y, early_stopping_rounds = 100, eval_metric='logloss',
                 eval_set = evals, verbose = True)
# Out:
# /opt/conda/envs/dove/lib/python3.8/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/envs/dove/lib/python3.8/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's binary_logloss: 0.587422
# [2]	valid_0's binary_logloss: 0.531149
# [3]	valid_0's binary_logloss: 0.482079
# [4]	valid_0's binary_logloss: 0.441809
# [5]	valid_0's binary_logloss: 0.404847
# [6]	valid_0's binary_logloss: 0.373771
# [7]	valid_0's binary_logloss: 0.348345
# [8]	valid_0's binary_logloss: 0.326205
# [9]	valid_0's binary_logloss: 0.308117
# [10]	valid_0's binary_logloss: 0.287913
# [11]	valid_0's binary_logloss: 0.270574
# [12]	valid_0's binary_logloss: 0.254553
# [13]	valid_0's binary_logloss: 0.240988
# [14]	valid_0's binary_logloss: 0.228982
# [15]	valid_0's binary_logloss: 0.220416
# [16]	valid_0's binary_logloss: 0.21066
# [17]	valid_0's binary_logloss: 0.202174
# [18]	valid_0's binary_logloss: 0.193189
# [19]	valid_0's binary_logloss: 0.185653
# [20]	valid_0's binary_logloss: 0.180484
# [21]	valid_0's binary_logloss: 0.172844
# [22]	valid_0's binary_logloss: 0.169735
# [23]	valid_0's binary_logloss: 0.163357
# [24]	valid_0's binary_logloss: 0.158586
# [25]	valid_0's binary_logloss: 0.156971
# [26]	valid_0's binary_logloss: 0.153013
# [27]	valid_0's binary_logloss: 0.148359
# [28]	valid_0's binary_logloss: 0.144886
# [29]	valid_0's binary_logloss: 0.140972
# [30]	valid_0's binary_logloss: 0.138223
# [31]	valid_0's binary_logloss: 0.135989
# [32]	valid_0's binary_logloss: 0.13289
# [33]	valid_0's binary_logloss: 0.129636
# [34]	valid_0's binary_logloss: 0.125661
# [35]	valid_0's binary_logloss: 0.124243
# [36]	valid_0's binary_logloss: 0.121815
# [37]	valid_0's binary_logloss: 0.120892
# [38]	valid_0's binary_logloss: 0.121439
# [39]	valid_0's binary_logloss: 0.119994
# [40]	valid_0's binary_logloss: 0.117986
# [41]	valid_0's binary_logloss: 0.118478
# [42]	valid_0's binary_logloss: 0.116621
# [43]	valid_0's binary_logloss: 0.114735
# [44]	valid_0's binary_logloss: 0.114592
# [45]	valid_0's binary_logloss: 0.115397
# [46]	valid_0's binary_logloss: 0.113235
# [47]	valid_0's binary_logloss: 0.112797
# [48]	valid_0's binary_logloss: 0.1141
# [49]	valid_0's binary_logloss: 0.114568
# [50]	valid_0's binary_logloss: 0.115116
# [51]	valid_0's binary_logloss: 0.115932
# [52]	valid_0's binary_logloss: 0.11638
# [53]	valid_0's binary_logloss: 0.116974
# [54]	valid_0's binary_logloss: 0.118401
# [55]	valid_0's binary_logloss: 0.120908
# [56]	valid_0's binary_logloss: 0.12141
# [57]	valid_0's binary_logloss: 0.122126
# [58]	valid_0's binary_logloss: 0.124689
# [59]	valid_0's binary_logloss: 0.125655
# [60]	valid_0's binary_logloss: 0.127187
# [61]	valid_0's binary_logloss: 0.126819
# [62]	valid_0's binary_logloss: 0.126745
# [63]	valid_0's binary_logloss: 0.124972
# [64]	valid_0's binary_logloss: 0.123212
# [65]	valid_0's binary_logloss: 0.123696
# [66]	valid_0's binary_logloss: 0.124574
# [67]	valid_0's binary_logloss: 0.125315
# [68]	valid_0's binary_logloss: 0.125581
# [69]	valid_0's binary_logloss: 0.126547
# [70]	valid_0's binary_logloss: 0.12689
# [71]	valid_0's binary_logloss: 0.127715
# [72]	valid_0's binary_logloss: 0.126782
# [73]	valid_0's binary_logloss: 0.126206
# [74]	valid_0's binary_logloss: 0.124139
# [75]	valid_0's binary_logloss: 0.124162
# [76]	valid_0's binary_logloss: 0.124637
# [77]	valid_0's binary_logloss: 0.12623
# [78]	valid_0's binary_logloss: 0.126774
# [79]	valid_0's binary_logloss: 0.126993
# [80]	valid_0's binary_logloss: 0.125905
# [81]	valid_0's binary_logloss: 0.126884
# [82]	valid_0's binary_logloss: 0.128599
# [83]	valid_0's binary_logloss: 0.127009
# [84]	valid_0's binary_logloss: 0.125517
# [85]	valid_0's binary_logloss: 0.125374
# [86]	valid_0's binary_logloss: 0.12705
# [87]	valid_0's binary_logloss: 0.128581
# [88]	valid_0's binary_logloss: 0.127004
# [89]	valid_0's binary_logloss: 0.127523
# [90]	valid_0's binary_logloss: 0.1274
# [91]	valid_0's binary_logloss: 0.127581
# [92]	valid_0's binary_logloss: 0.127247
# [93]	valid_0's binary_logloss: 0.128721
# [94]	valid_0's binary_logloss: 0.130788
# [95]	valid_0's binary_logloss: 0.130503
# [96]	valid_0's binary_logloss: 0.129735
# [97]	valid_0's binary_logloss: 0.130481
# [98]	valid_0's binary_logloss: 0.130033
# [99]	valid_0's binary_logloss: 0.12992
# [100]	valid_0's binary_logloss: 0.131333
# [101]	valid_0's binary_logloss: 0.130993
# [102]	valid_0's binary_logloss: 0.130729
# [103]	valid_0's binary_logloss: 0.131433
# [104]	valid_0's binary_logloss: 0.131425
# [105]	valid_0's binary_logloss: 0.132282
# [106]	valid_0's binary_logloss: 0.134606
# [107]	valid_0's binary_logloss: 0.135167
# [108]	valid_0's binary_logloss: 0.13753
# [109]	valid_0's binary_logloss: 0.137991
# [110]	valid_0's binary_logloss: 0.139683
# [111]	valid_0's binary_logloss: 0.142403
# [112]	valid_0's binary_logloss: 0.142983
# [113]	valid_0's binary_logloss: 0.145801
# [114]	valid_0's binary_logloss: 0.147256
# [115]	valid_0's binary_logloss: 0.148302
# [116]	valid_0's binary_logloss: 0.148798
# [117]	valid_0's binary_logloss: 0.151392
# [118]	valid_0's binary_logloss: 0.154308
# [119]	valid_0's binary_logloss: 0.15731
# [120]	valid_0's binary_logloss: 0.159937
# [121]	valid_0's binary_logloss: 0.162825
# [122]	valid_0's binary_logloss: 0.163292
# [123]	valid_0's binary_logloss: 0.165477
# [124]	valid_0's binary_logloss: 0.1686
# [125]	valid_0's binary_logloss: 0.170698
# [126]	valid_0's binary_logloss: 0.173173
# [127]	valid_0's binary_logloss: 0.173573
# [128]	valid_0's binary_logloss: 0.175672
# [129]	valid_0's binary_logloss: 0.177676
# [130]	valid_0's binary_logloss: 0.178241
# [131]	valid_0's binary_logloss: 0.178664
# [132]	valid_0's binary_logloss: 0.18213
# [133]	valid_0's binary_logloss: 0.184483
# [134]	valid_0's binary_logloss: 0.185121
# [135]	valid_0's binary_logloss: 0.185354
# [136]	valid_0's binary_logloss: 0.188386
# [137]	valid_0's binary_logloss: 0.188996
# [138]	valid_0's binary_logloss: 0.191032
# [139]	valid_0's binary_logloss: 0.189505
# [140]	valid_0's binary_logloss: 0.189211
# [141]	valid_0's binary_logloss: 0.188954
# [142]	valid_0's binary_logloss: 0.190498
# [143]	valid_0's binary_logloss: 0.191215
# [144]	valid_0's binary_logloss: 0.191366
# [145]	valid_0's binary_logloss: 0.191898
# [146]	valid_0's binary_logloss: 0.19042
# [147]	valid_0's binary_logloss: 0.190065
# LGBMClassifier(n_estimators=400)

# %%
pred       = lgbm_wrapper.predict(test_x)
pred_proba = lgbm_wrapper.predict_proba(test_x)[:1]
get_clf_eval(test_y, pred)
# Out:
# confusion matrix
# [[39  3]
#  [ 1 71]]
#
# accuracy  : 0.965
# precision : 0.959
# recall    : 0.986
# F1 score  : 0.973
# AUC score : 0.957
