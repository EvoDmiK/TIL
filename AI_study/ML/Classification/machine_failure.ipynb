# %%
from collections import Counter
import os

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from catboost import CatBoostClassifier
from pycaret.classification import *
import matplotlib.pyplot as plt
from sklearn.metrics import *
from sklearn.svm import SVC
import seaborn as sns
import pandas as pd
import numpy as np

# %%
SEP       = os.path.sep
ROOT_PATH = SEP.join(os.getcwd().split(SEP)[ :-3])
DATA_PATH = f'{ROOT_PATH}/Dataset/machine failure'

# %%
def draw_histplot(column, *dfs):
    
    fig, ax = plt.subplots(1, 3, figsize = (24, 7))
    for idx, (name, df_) in enumerate(zip(['total', 'normal', 'abnormal'], dfs)):
        
        sns.histplot(df_[column], kde = True, ax = ax[idx])
        ax[idx].set_title(f'{name} - {column} histplot')
        
        
    plt.show()
    

def draw_data_distribution(y_values):
    
    fig, ax = plt.subplots(1, 2, figsize = (15, 7))
    for idx, (dtype, y_value) in enumerate(zip(['train', 'valid'], y_values)):
        
        count = Counter(y_value)
        ax[idx].bar(count.keys(), count.values())
        for k, v in count.items():
            
            ax[idx].text(k, v, v,
                         va = 'bottom',
                         ha = 'center')
            ax[idx].set_title(f'{dtype} data distribution')
            
    plt.show()
    
    
def metrics_report(test_y, pred_y, dtype = 'train'):
    print(f'classification report for {dtype}\n{classification_report(test_y, pred_y)}')
    print(f'AUC score for {dtype} : {roc_auc_score(test_y, pred_y):.3f}')
    
    
def evaluation(model, method):
    
    os.makedirs('submissions', exist_ok = True)
    
    submission = pd.read_csv(f'{DATA_PATH}/sample_submission.csv')
    test_df    = pd.read_csv(f'{DATA_PATH}/test.csv')

    test_df.drop(['id', 'Product ID'], axis = 1, inplace = True)
    test_df['Type'] = le.fit_transform(test_df['Type'])
    test_df         = scaler.transform(test_df)

    pred_y = model.predict(test_df)

    submission['Machine failure'] = pred_y
    submission.to_csv(f'submissions/submission_{method}.csv', index = False)

# %%
df        = pd.read_csv(f'{DATA_PATH}/train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136429 entries, 0 to 136428
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       136429 non-null  int64
#  1   Product ID               136429 non-null  object
#  2   Type                     136429 non-null  object
#  3   Air temperature [K]      136429 non-null  float64
#  4   Process temperature [K]  136429 non-null  float64
#  5   Rotational speed [rpm]   136429 non-null  int64
#  6   Torque [Nm]              136429 non-null  float64
#  7   Tool wear [min]          136429 non-null  int64
#  8   Machine failure          136429 non-null  int64
#  9   TWF                      136429 non-null  int64
#  10  HDF                      136429 non-null  int64
#  11  PWF                      136429 non-null  int64
#  12  OSF                      136429 non-null  int64
#  13  RNF                      136429 non-null  int64
# dtypes: float64(3), int64(9), object(2)
# memory usage: 14.6+ MB

# %%
normal   = df[df['Machine failure'] == 0]
abnormal = df[df['Machine failure'] == 1]

# %%
draw_histplot('Air temperature [K]', *[df, normal, abnormal])

# %%
draw_histplot('Rotational speed [rpm]', *[df, normal, abnormal])

# %%
draw_histplot('Torque [Nm]', *[df, normal, abnormal])

# %%
le = LabelEncoder()
df['Type'] = le.fit_transform(df['Type'])
df.drop(['id', 'Product ID'], axis = 1, inplace = True)
df.head(3)
# Out:
#    Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0     1                300.6                    309.6                    1596
# 1     2                302.6                    312.1                    1759
# 2     1                299.3                    308.5                    1805
#
#    Torque [Nm]  Tool wear [min]  Machine failure  TWF  HDF  PWF  OSF  RNF
# 0         36.1              140                0    0    0    0    0    0
# 1         29.1              200                0    0    0    0    0    0
# 2         26.5               25                0    0    0    0    0    0

# %%
X = df.drop('Machine failure', axis = 1)
y = df['Machine failure']

X.shape, y.shape, df.shape
# Out:
# ((136429, 11), (136429,), (136429, 12))

# %%
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size = 0.25, stratify = y,
                                                    random_state    =   99,  shuffle = True)

draw_data_distribution([train_y, test_y])

# %%
scaler  = StandardScaler()
train_x = scaler.fit_transform(train_x)
test_x  = scaler.transform(test_x)

# %%
svm = SVC()
svm.fit(train_x, train_y)
# Out:
# SVC()

# %%
pred_y = svm.predict(train_x)
metrics_report(pred_y, train_y, dtype = 'train')
# Out:
# classification report for train
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    101086
#            1       0.76      0.99      0.86      1235
#
#     accuracy                           1.00    102321
#    macro avg       0.88      0.99      0.93    102321
# weighted avg       1.00      1.00      1.00    102321
#
# AUC score for train : 0.994

# %%
pred_y = svm.predict(test_x)
metrics_report(pred_y, test_y, dtype = 'test')

evaluation(svm, 'SVC_no_SMOTE')
# Out:
# classification report for test
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     33689
#            1       0.77      0.99      0.87       419
#
#     accuracy                           1.00     34108
#    macro avg       0.89      0.99      0.93     34108
# weighted avg       1.00      1.00      1.00     34108
#
# AUC score for test : 0.993

# %%
sampler          = SMOTE(random_state = 99)
train_x, train_y = sampler.fit_resample(train_x, train_y)

# %%
count = Counter(train_y)
plt.bar(count.keys(), count.values())
for k, v in count.items():

    plt.text(k, v, v,
                 va = 'bottom',
                 ha = 'center')

# %%
svm = SVC()
svm.fit(train_x, train_y)
# Out:
# SVC()

# %%
pred_y = svm.predict(train_x)
metrics_report(pred_y, train_y)
# Out:
# classification report for train
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91    116462
#            1       0.83      0.98      0.90     84958
#
#     accuracy                           0.90    201420
#    macro avg       0.90      0.91      0.90    201420
# weighted avg       0.92      0.90      0.91    201420
#
# AUC score for train : 0.915

# %%
pred_y = svm.predict(test_x)
metrics_report(pred_y, test_y, dtype = 'test')

evaluation(svm, 'SVC_SMOTE')
# Out:
# classification report for test
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     33093
#            1       0.83      0.44      0.57      1015
#
#     accuracy                           0.98     34108
#    macro avg       0.91      0.72      0.78     34108
# weighted avg       0.98      0.98      0.98     34108
#
# AUC score for test : 0.718

# %%
model = GradientBoostingClassifier(random_state = 99)
model.fit(train_x, train_y)
# Out:
# GradientBoostingClassifier(random_state=99)

# %%
pred_y = model.predict(train_x)
metrics_report(pred_y, train_y)
# Out:
# classification report for train
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92    108643
#            1       0.88      0.96      0.92     92777
#
#     accuracy                           0.92    201420
#    macro avg       0.92      0.92      0.92    201420
# weighted avg       0.93      0.92      0.92    201420
#
# AUC score for train : 0.925

# %%
pred_y = model.predict(test_x)
metrics_report(pred_y, test_y, dtype = 'test')

evaluation(model, 'GBM')
# Out:
# classification report for test
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     32391
#            1       0.86      0.27      0.41      1717
#
#     accuracy                           0.96     34108
#    macro avg       0.91      0.63      0.69     34108
# weighted avg       0.96      0.96      0.95     34108
#
# AUC score for test : 0.633

# %%
model     = CatBoostClassifier(iterations  = 100, loss_function = 'CrossEntropy', 
                           random_seed     = 99, learning_rate = 0.3, verbose = False)
model.fit(train_x, train_y,
          eval_set = (test_x, test_y)
          )

# %%
pred_y = model.predict(train_x)
metrics_report(pred_y, train_y, dtype = 'train')
# Out:
# classification report for train
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97    105093
#            1       0.94      0.99      0.97     96327
#
#     accuracy                           0.97    201420
#    macro avg       0.97      0.97      0.97    201420
# weighted avg       0.97      0.97      0.97    201420
#
# AUC score for train : 0.968

# %%
pred_y = model.predict(test_x)
metrics_report(pred_y, test_y, dtype = 'test')

evaluation(model, 'CatBoosting')
# Out:
# classification report for test
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     33279
#            1       0.82      0.53      0.65       829
#
#     accuracy                           0.99     34108
#    macro avg       0.91      0.77      0.82     34108
# weighted avg       0.98      0.99      0.98     34108
#
# AUC score for test : 0.766

# %%
setup_clf = setup(data = df       , target = 'Machine failure', 
                  train_size = 0.8, fold = 10, 
                  fix_imbalance = True, fix_imbalance_method = "tomeklinks")
# Out:
# <style type="text/css">
# #T_80635_row8_col1, #T_80635_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_80635">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80635_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_80635_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80635_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80635_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_80635_row0_col1" class="data row0 col1" >4750</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80635_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_80635_row1_col1" class="data row1 col1" >Machine failure</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80635_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_80635_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80635_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_80635_row3_col1" class="data row3 col1" >(136429, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80635_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_80635_row4_col1" class="data row4 col1" >(135873, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_80635_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_80635_row5_col1" class="data row5 col1" >(108587, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_80635_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_80635_row6_col1" class="data row6 col1" >(27286, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_80635_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_80635_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_80635_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_80635_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_80635_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_80635_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_80635_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_80635_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_80635_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_80635_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_80635_row12_col0" class="data row12 col0" >Fix imbalance</td>
#       <td id="T_80635_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_80635_row13_col0" class="data row13 col0" >Fix imbalance method</td>
#       <td id="T_80635_row13_col1" class="data row13 col1" >tomeklinks</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_80635_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_80635_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_80635_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_80635_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_80635_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_80635_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_80635_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_80635_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_80635_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_80635_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_80635_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_80635_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_80635_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_80635_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_80635_row20_col1" class="data row20 col1" >3511</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models(sort = 'AUC')
# Out:
# <style type="text/css">
# #T_60c50 th {
#   text-align: left;
# }
# #T_60c50_row0_col0, #T_60c50_row0_col1, #T_60c50_row0_col3, #T_60c50_row0_col4, #T_60c50_row0_col5, #T_60c50_row0_col6, #T_60c50_row0_col7, #T_60c50_row1_col0, #T_60c50_row1_col1, #T_60c50_row1_col2, #T_60c50_row1_col3, #T_60c50_row1_col4, #T_60c50_row1_col5, #T_60c50_row1_col6, #T_60c50_row1_col7, #T_60c50_row2_col0, #T_60c50_row2_col1, #T_60c50_row2_col2, #T_60c50_row2_col3, #T_60c50_row2_col4, #T_60c50_row2_col7, #T_60c50_row3_col0, #T_60c50_row3_col1, #T_60c50_row3_col2, #T_60c50_row3_col3, #T_60c50_row3_col4, #T_60c50_row3_col5, #T_60c50_row3_col6, #T_60c50_row3_col7, #T_60c50_row4_col0, #T_60c50_row4_col1, #T_60c50_row4_col2, #T_60c50_row4_col3, #T_60c50_row4_col4, #T_60c50_row4_col5, #T_60c50_row4_col6, #T_60c50_row4_col7, #T_60c50_row5_col0, #T_60c50_row5_col1, #T_60c50_row5_col2, #T_60c50_row5_col3, #T_60c50_row5_col4, #T_60c50_row5_col5, #T_60c50_row5_col6, #T_60c50_row5_col7, #T_60c50_row6_col0, #T_60c50_row6_col1, #T_60c50_row6_col2, #T_60c50_row6_col3, #T_60c50_row6_col4, #T_60c50_row6_col5, #T_60c50_row6_col6, #T_60c50_row6_col7, #T_60c50_row7_col0, #T_60c50_row7_col1, #T_60c50_row7_col2, #T_60c50_row7_col3, #T_60c50_row7_col4, #T_60c50_row7_col5, #T_60c50_row7_col6, #T_60c50_row7_col7, #T_60c50_row8_col0, #T_60c50_row8_col2, #T_60c50_row8_col3, #T_60c50_row8_col5, #T_60c50_row8_col6, #T_60c50_row9_col0, #T_60c50_row9_col1, #T_60c50_row9_col2, #T_60c50_row9_col3, #T_60c50_row9_col4, #T_60c50_row9_col5, #T_60c50_row9_col6, #T_60c50_row9_col7, #T_60c50_row10_col0, #T_60c50_row10_col1, #T_60c50_row10_col2, #T_60c50_row10_col3, #T_60c50_row10_col4, #T_60c50_row10_col5, #T_60c50_row10_col6, #T_60c50_row10_col7, #T_60c50_row11_col0, #T_60c50_row11_col1, #T_60c50_row11_col2, #T_60c50_row11_col4, #T_60c50_row11_col5, #T_60c50_row11_col6, #T_60c50_row11_col7, #T_60c50_row12_col0, #T_60c50_row12_col1, #T_60c50_row12_col2, #T_60c50_row12_col3, #T_60c50_row12_col4, #T_60c50_row12_col5, #T_60c50_row12_col6, #T_60c50_row12_col7, #T_60c50_row13_col0, #T_60c50_row13_col1, #T_60c50_row13_col2, #T_60c50_row13_col3, #T_60c50_row13_col4, #T_60c50_row13_col5, #T_60c50_row13_col6, #T_60c50_row13_col7, #T_60c50_row14_col0, #T_60c50_row14_col2, #T_60c50_row14_col3, #T_60c50_row14_col5, #T_60c50_row14_col6 {
#   text-align: left;
# }
# #T_60c50_row0_col2, #T_60c50_row2_col5, #T_60c50_row2_col6, #T_60c50_row8_col1, #T_60c50_row8_col4, #T_60c50_row8_col7, #T_60c50_row11_col3, #T_60c50_row14_col1, #T_60c50_row14_col4, #T_60c50_row14_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_60c50_row0_col8, #T_60c50_row1_col8, #T_60c50_row2_col8, #T_60c50_row3_col8, #T_60c50_row4_col8, #T_60c50_row5_col8, #T_60c50_row6_col8, #T_60c50_row7_col8, #T_60c50_row8_col8, #T_60c50_row9_col8, #T_60c50_row10_col8, #T_60c50_row12_col8, #T_60c50_row13_col8, #T_60c50_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_60c50_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_60c50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60c50_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_60c50_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_60c50_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_60c50_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_60c50_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_60c50_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_60c50_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_60c50_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_60c50_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60c50_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_60c50_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_60c50_row0_col1" class="data row0 col1" >0.9961</td>
#       <td id="T_60c50_row0_col2" class="data row0 col2" >0.9641</td>
#       <td id="T_60c50_row0_col3" class="data row0 col3" >0.7765</td>
#       <td id="T_60c50_row0_col4" class="data row0 col4" >0.9666</td>
#       <td id="T_60c50_row0_col5" class="data row0 col5" >0.8608</td>
#       <td id="T_60c50_row0_col6" class="data row0 col6" >0.8589</td>
#       <td id="T_60c50_row0_col7" class="data row0 col7" >0.8643</td>
#       <td id="T_60c50_row0_col8" class="data row0 col8" >0.2850</td>
#     </tr>
#     <tr>
#       <th id="T_60c50_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_60c50_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_60c50_row1_col1" class="data row1 col1" >0.9963</td>
#       <td id="T_60c50_row1_col2" class="data row1 col2" >0.9604</td>
#       <td id="T_60c50_row1_col3" class="data row1 col3" >0.7811</td>
#       <td id="T_60c50_row1_col4" class="data row1 col4" >0.9761</td>
#       <td id="T_60c50_row1_col5" class="data row1 col5" >0.8674</td>
#       <td id="T_60c50_row1_col6" class="data row1 col6" >0.8655</td>
#       <td id="T_60c50_row1_col7" class="data row1 col7" >0.8713</td>
#       <td id="T_60c50_row1_col8" class="data row1 col8" >1.0820</td>
#     </tr>
#     <tr>
#       <th id="T_60c50_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_60c50_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_60c50_row2_col1" class="data row2 col1" >0.9963</td>
#       <td id="T_60c50_row2_col2" class="data row2 col2" >0.9597</td>
#       <td id="T_60c50_row2_col3" class="data row2 col3" >0.7782</td>
#       <td id="T_60c50_row2_col4" class="data row2 col4" >0.9860</td>
#       <td id="T_60c50_row2_col5" class="data row2 col5" >0.8695</td>
#       <td id="T_60c50_row2_col6" class="data row2 col6" >0.8676</td>
#       <td id="T_60c50_row2_col7" class="data row2 col7" >0.8741</td>
#       <td id="T_60c50_row2_col8" class="data row2 col8" >0.4400</td>
#     </tr>
#     <tr>
#       <th id="T_60c50_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_60c50_row3_col0" class="data row3 col0" >CatBoost Classifier</td>
#       <td id="T_60c50_row3_col1" class="data row3 col1" >0.9961</td>
#       <td id="T_60c50_row3_col2" class="data row3 col2" >0.9577</td>
#       <td id="T_60c50_row3_col3" class="data row3 col3" >0.7759</td>
#       <td id="T_60c50_row3_col4" class="data row3 col4" >0.9725</td>
#       <td id="T_60c50_row3_col5" class="data row3 col5" >0.8627</td>
#       <td id="T_60c50_row3_col6" class="data row3 col6" >0.8607</td>
#       <td id="T_60c50_row3_col7" class="data row3 col7" >0.8666</td>
#       <td id="T_60c50_row3_col8" class="data row3 col8" >29.8820</td>
#     </tr>
#     <tr>
#       <th id="T_60c50_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_60c50_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_60c50_row4_col1" class="data row4 col1" >0.9943</td>
#       <td id="T_60c50_row4_col2" class="data row4 col2" >0.9485</td>
#       <td id="T_60c50_row4_col3" class="data row4 col3" >0.7788</td>
#       <td id="T_60c50_row4_col4" class="data row4 col4" >0.8530</td>
#       <td id="T_60c50_row4_col5" class="data row4 col5" >0.8126</td>
#       <td id="T_60c50_row4_col6" class="data row4 col6" >0.8098</td>
#       <td id="T_60c50_row4_col7" class="data row4 col7" >0.8114</td>
#       <td id="T_60c50_row4_col8" class="data row4 col8" >0.2370</td>
#     </tr>
#     <tr>
#       <th id="T_60c50_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_60c50_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_60c50_row5_col1" class="data row5 col1" >0.9961</td>
#       <td id="T_60c50_row5_col2" class="data row5 col2" >0.9421</td>
#       <td id="T_60c50_row5_col3" class="data row5 col3" >0.7776</td>
#       <td id="T_60c50_row5_col4" class="data row5 col4" >0.9688</td>
#       <td id="T_60c50_row5_c

# %%
model       = create_model('lda')
tuned_model = tune_model(model)
# Out:
# <style type="text/css">
# #T_01a83_row10_col0, #T_01a83_row10_col1, #T_01a83_row10_col2, #T_01a83_row10_col3, #T_01a83_row10_col4, #T_01a83_row10_col5, #T_01a83_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_01a83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01a83_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_01a83_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_01a83_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_01a83_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_01a83_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_01a83_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_01a83_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01a83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01a83_row0_col0" class="data row0 col0" >0.9972</td>
#       <td id="T_01a83_row0_col1" class="data row0 col1" >0.9465</td>
#       <td id="T_01a83_row0_col2" class="data row0 col2" >0.8198</td>
#       <td id="T_01a83_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_01a83_row0_col4" class="data row0 col4" >0.9010</td>
#       <td id="T_01a83_row0_col5" class="data row0 col5" >0.8995</td>
#       <td id="T_01a83_row0_col6" class="data row0 col6" >0.9041</td>
#     </tr>
#     <tr>
#       <th id="T_01a83_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_01a83_row1_col0" class="data row1 col0" >0.9960</td>
#       <td id="T_01a83_row1_col1" class="data row1 col1" >0.9329</td>
#       <td id="T_01a83_row1_col2" class="data row1 col2" >0.7442</td>
#       <td id="T_01a83_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_01a83_row1_col4" class="data row1 col4" >0.8533</td>
#       <td id="T_01a83_row1_col5" class="data row1 col5" >0.8513</td>
#       <td id="T_01a83_row1_col6" class="data row1 col6" >0.8609</td>
#     </tr>
#     <tr>
#       <th id="T_01a83_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_01a83_row2_col0" class="data row2 col0" >0.9958</td>
#       <td id="T_01a83_row2_col1" class="data row2 col1" >0.9178</td>
#       <td id="T_01a83_row2_col2" class="data row2 col2" >0.7384</td>
#       <td id="T_01a83_row2_col3" class="data row2 col3" >0.9922</td>
#       <td id="T_01a83_row2_col4" class="data row2 col4" >0.8467</td>
#       <td id="T_01a83_row2_col5" class="data row2 col5" >0.8446</td>
#       <td id="T_01a83_row2_col6" class="data row2 col6" >0.8541</td>
#     </tr>
#     <tr>
#       <th id="T_01a83_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_01a83_row3_col0" class="data row3 col0" >0.9965</td>
#       <td id="T_01a83_row3_col1" class="data row3 col1" >0.9230</td>
#       <td id="T_01a83_row3_col2" class="data row3 col2" >0.7778</td>
#       <td id="T_01a83_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_01a83_row3_col4" class="data row3 col4" >0.8750</td>
#       <td id="T_01a83_row3_col5" class="data row3 col5" >0.8733</td>
#       <td id="T_01a83_row3_col6" class="data row3 col6" >0.8804</td>
#     </tr>
#     <tr>
#       <th id="T_01a83_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_01a83_row4_col0" class="data row4 col0" >0.9961</td>
#       <td id="T_01a83_row4_col1" class="data row4 col1" >0.9390</td>
#       <td id="T_01a83_row4_col2" class="data row4 col2" >0.7544</td>
#       <td id="T_01a83_row4_col3" class="data row4 col3" >0.9923</td>
#       <td id="T_01a83_row4_col4" class="data row4 col4" >0.8571</td>
#       <td id="T_01a83_row4_col5" class="data row4 col5" >0.8552</td>
#       <td id="T_01a83_row4_col6" class="data row4 col6" >0.8635</td>
#     </tr>
#     <tr>
#       <th id="T_01a83_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_01a83_row5_col0" class="data row5 col0" >0.9964</td>
#       <td id="T_01a83_row5_col1" class="data row5 col1" >0.9399</td>
#       <td id="T_01a83_row5_col2" class="data row5 col2" >0.7733</td>
#       <td id="T_01a83_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_01a83_row5_col4" class="data row5 col4" >0.8721</td>
#       <td id="T_01a83_row5_col5" class="data row5 col5" >0.8703</td>
#       <td id="T_01a83_row5_col6" class="data row5 col6" >0.8778</td>
#     </tr>
#     <tr>
#       <th id="T_01a83_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_01a83_row6_col0" class="data row6 col0" >0.9954</td>
#       <td id="T_01a83_row6_col1" class="data row6 col1" >0.9315</td>
#       <td id="T_01a83_row6_col2" class="data row6 col2" >0.7209</td>
#       <td id="T_01a83_row6_col3" class="data row6 col3" >0.9841</td>
#       <td id="T_01a83_row6_col4" class="data row6 col4" >0.8322</td>
#       <td id="T_01a83_row6_col5" class="data row6 col5" >0.8299</td>
#       <td id="T_01a83_row6_col6" class="data row6 col6" >0.8403</td>
#     </tr>
#     <tr>
#       <th id="T_01a83_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_01a83_row7_col0" class="data row7 col0" >0.9970</td>
#       <td id="T_01a83_row7_col1" class="data row7 col1" >0.9523</td>
#       <td id="T_01a83_row7_col2" class="data row7 col2" >0.8081</td>
#       <td id="T_01a83_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_01a83_row7_col4" class="data row7 col4" >0.8939</td>
#       <td id="T_01a83_row7_col5" class="data row7 col5" >0.8924</td>
#       <td id="T_01a83_row7_col6" class="data row7 col6" >0.8976</td>
#     </tr>
#     <tr>
#       <th id="T_01a83_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_01a83_row8_col0" class="data row8 col0" >0.9972</td>
#       <td id="T_01a83_row8_col1" class="data row8 col1" >0.9547</td>
#       <td id="T_01a83_row8_col2" class="data row8 col2" >0.8256</td>
#       <td id="T_01a83_row8_col3" class="data row8 col3" >0.9930</td>
#       <td id="T_01a83_row8_col4" class="data row8 col4" >0.9016</td>
#       <td id="T_01a83_row8_col5" class="data row8 col5" >0.9002</td>
#       <td id="T_01a83_row8_col6" class="data row8 col6" >0.9041</td>
#     </tr>
#     <tr>
#       <th id="T_01a83_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_01a83_row9_col0" class="data row9 col0" >0.9961</td>
#       <td id="T_01a83_row9_col1" class="data row9 col1" >0.9218</td>
#       <td id="T_01a83_row9_col2" class="data row9 col2" >0.7616</td>
#       <td id="T_01a83_row9_col3" class="data row9 col3" >0.9850</td>
#       <td id="T_01a83_row9_col4" class="data row9 col4" >0.8590</td>
#       <td id="T_01a83_row9_col5" class="data row9 col5" >0.8571</td>
#       <td id="T_01a83_row9_col6" class="data row9 col6" >0.8643</td>
#     </tr>
#     <tr>
#       <th id="T_01a83_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_01a83_row10_col0" class="data row10 col0" >0.9964</td>
#       <td id="T_01a83_row10_col1" class="data row10 col1" >0.9359</td>
#       <td id="T_01a83_row10_col2" class="data row10 col2" >0.7724</td>
#       <td id="T_01a83_row10_col3" class="data row10 col3" >0.9947</td>
#       <td id="T_01a83_row10_col4" class="data row10 col4" >0.8692</td>
#       <td id="T_01a83_row10_col5" class="data row10 col5" >0.8674</td>
#       <td id="T_01a83_row10_col6" class="data row10 col6" >0.8747</td>
#     </tr>
#     <tr>
#       <th id="T_01a83_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_01a83_row11_col0" class="data row11 col0" >0.0006</td>
#       <td id="T_01a83_row11_col1" class="data row11 col1" >0.0122</td>
#       <td id="T_01a83_row11_col2" class="data row11 col2" >0.0338</td>
#       <td id="T_01a83_row11_col3" class="data row11 col3" >0.0060</td>
#       <td id="T_01a83_row11_col4
# <style type="text/css">
# #T_78a50_row10_col0, #T_78a50_row10_col1, #T_78a50_row10_col2, #T_78a50_row10_col3, #T_78a50_row10_col4, #T_78a50_row10_col5, #T_78a50_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_78a50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78a50_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_78a50_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_78a50_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_78a50_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_78a50_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_78a50_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_78a50_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78a50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78a50_row0_col0" class="data row0 col0" >0.9963</td>
#       <td id="T_78a50_row0_col1" class="data row0 col1" >0.9395</td>
#       <td id="T_78a50_row0_col2" class="data row0 col2" >0.7674</td>
#       <td id="T_78a50_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_78a50_row0_col4" class="data row0 col4" >0.8684</td>
#       <td id="T_78a50_row0_col5" class="data row0 col5" >0.8666</td>
#       <td id="T_78a50_row0_col6" class="data row0 col6" >0.8744</td>
#     </tr>
#     <tr>
#       <th id="T_78a50_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78a50_row1_col0" class="data row1 col0" >0.9949</td>
#       <td id="T_78a50_row1_col1" class="data row1 col1" >0.9174</td>
#       <td id="T_78a50_row1_col2" class="data row1 col2" >0.6744</td>
#       <td id="T_78a50_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_78a50_row1_col4" class="data row1 col4" >0.8056</td>
#       <td id="T_78a50_row1_col5" class="data row1 col5" >0.8031</td>
#       <td id="T_78a50_row1_col6" class="data row1 col6" >0.8191</td>
#     </tr>
#     <tr>
#       <th id="T_78a50_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_78a50_row2_col0" class="data row2 col0" >0.9944</td>
#       <td id="T_78a50_row2_col1" class="data row2 col1" >0.9105</td>
#       <td id="T_78a50_row2_col2" class="data row2 col2" >0.6512</td>
#       <td id="T_78a50_row2_col3" class="data row2 col3" >0.9912</td>
#       <td id="T_78a50_row2_col4" class="data row2 col4" >0.7860</td>
#       <td id="T_78a50_row2_col5" class="data row2 col5" >0.7833</td>
#       <td id="T_78a50_row2_col6" class="data row2 col6" >0.8011</td>
#     </tr>
#     <tr>
#       <th id="T_78a50_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_78a50_row3_col0" class="data row3 col0" >0.9958</td>
#       <td id="T_78a50_row3_col1" class="data row3 col1" >0.8965</td>
#       <td id="T_78a50_row3_col2" class="data row3 col2" >0.7310</td>
#       <td id="T_78a50_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_78a50_row3_col4" class="data row3 col4" >0.8446</td>
#       <td id="T_78a50_row3_col5" class="data row3 col5" >0.8425</td>
#       <td id="T_78a50_row3_col6" class="data row3 col6" >0.8532</td>
#     </tr>
#     <tr>
#       <th id="T_78a50_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_78a50_row4_col0" class="data row4 col0" >0.9950</td>
#       <td id="T_78a50_row4_col1" class="data row4 col1" >0.9396</td>
#       <td id="T_78a50_row4_col2" class="data row4 col2" >0.6842</td>
#       <td id="T_78a50_row4_col3" class="data row4 col3" >0.9915</td>
#       <td id="T_78a50_row4_col4" class="data row4 col4" >0.8097</td>
#       <td id="T_78a50_row4_col5" class="data row4 col5" >0.8072</td>
#       <td id="T_78a50_row4_col6" class="data row4 col6" >0.8215</td>
#     </tr>
#     <tr>
#       <th id="T_78a50_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_78a50_row5_col0" class="data row5 col0" >0.9944</td>
#       <td id="T_78a50_row5_col1" class="data row5 col1" >0.9115</td>
#       <td id="T_78a50_row5_col2" class="data row5 col2" >0.6453</td>
#       <td id="T_78a50_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_78a50_row5_col4" class="data row5 col4" >0.7845</td>
#       <td id="T_78a50_row5_col5" class="data row5 col5" >0.7818</td>
#       <td id="T_78a50_row5_col6" class="data row5 col6" >0.8011</td>
#     </tr>
#     <tr>
#       <th id="T_78a50_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_78a50_row6_col0" class="data row6 col0" >0.9940</td>
#       <td id="T_78a50_row6_col1" class="data row6 col1" >0.9007</td>
#       <td id="T_78a50_row6_col2" class="data row6 col2" >0.6279</td>
#       <td id="T_78a50_row6_col3" class="data row6 col3" >0.9818</td>
#       <td id="T_78a50_row6_col4" class="data row6 col4" >0.7660</td>
#       <td id="T_78a50_row6_col5" class="data row6 col5" >0.7630</td>
#       <td id="T_78a50_row6_col6" class="data row6 col6" >0.7827</td>
#     </tr>
#     <tr>
#       <th id="T_78a50_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_78a50_row7_col0" class="data row7 col0" >0.9960</td>
#       <td id="T_78a50_row7_col1" class="data row7 col1" >0.9444</td>
#       <td id="T_78a50_row7_col2" class="data row7 col2" >0.7442</td>
#       <td id="T_78a50_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_78a50_row7_col4" class="data row7 col4" >0.8533</td>
#       <td id="T_78a50_row7_col5" class="data row7 col5" >0.8513</td>
#       <td id="T_78a50_row7_col6" class="data row7 col6" >0.8609</td>
#     </tr>
#     <tr>
#       <th id="T_78a50_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_78a50_row8_col0" class="data row8 col0" >0.9951</td>
#       <td id="T_78a50_row8_col1" class="data row8 col1" >0.9199</td>
#       <td id="T_78a50_row8_col2" class="data row8 col2" >0.6919</td>
#       <td id="T_78a50_row8_col3" class="data row8 col3" >0.9917</td>
#       <td id="T_78a50_row8_col4" class="data row8 col4" >0.8151</td>
#       <td id="T_78a50_row8_col5" class="data row8 col5" >0.8126</td>
#       <td id="T_78a50_row8_col6" class="data row8 col6" >0.8262</td>
#     </tr>
#     <tr>
#       <th id="T_78a50_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_78a50_row9_col0" class="data row9 col0" >0.9930</td>
#       <td id="T_78a50_row9_col1" class="data row9 col1" >0.8909</td>
#       <td id="T_78a50_row9_col2" class="data row9 col2" >0.5640</td>
#       <td id="T_78a50_row9_col3" class="data row9 col3" >0.9898</td>
#       <td id="T_78a50_row9_col4" class="data row9 col4" >0.7185</td>
#       <td id="T_78a50_row9_col5" class="data row9 col5" >0.7153</td>
#       <td id="T_78a50_row9_col6" class="data row9 col6" >0.7444</td>
#     </tr>
#     <tr>
#       <th id="T_78a50_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_78a50_row10_col0" class="data row10 col0" >0.9949</td>
#       <td id="T_78a50_row10_col1" class="data row10 col1" >0.9171</td>
#       <td id="T_78a50_row10_col2" class="data row10 col2" >0.6781</td>
#       <td id="T_78a50_row10_col3" class="data row10 col3" >0.9946</td>
#       <td id="T_78a50_row10_col4" class="data row10 col4" >0.8052</td>
#       <td id="T_78a50_row10_col5" class="data row10 col5" >0.8027</td>
#       <td id="T_78a50_row10_col6" class="data row10 col6" >0.8185</td>
#     </tr>
#     <tr>
#       <th id="T_78a50_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_78a50_row11_col0" class="data row11 col0" >0.0009</td>
#       <td id="T_78a50_row11_col1" class="data row11 col1" >0.0179</td>
#       <td id="T_78a50_row11_col2" class="data row11 col2" >0.0572</td>
#       <td id="T_78a50_row11_col3" class="data row11 col3" >0.0060</td>
#       <td id="T_78a50_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
plot_model(tuned_model)

# %%
submission = pd.read_csv(f'{DATA_PATH}/sample_submission.csv')
test_df    = pd.read_csv(f'{DATA_PATH}/test.csv')

test_df.drop(['id', 'Product ID'], axis = 1, inplace = True)
test_df['Type'] = le.fit_transform(test_df['Type'])

# %%
final_model = finalize_model(tuned_model)
prediction  = predict_model(final_model, test_df)

# %%
submission['Machine failure'] = prediction['prediction_label']
submission.to_csv(f'submissions/submission_pycaret.csv', index = False)
