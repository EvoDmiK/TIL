# %% [markdown]
# # **0. 참고자료**
# ## **0-1. 도서**
# ## **0-2. 논문, 학술지**
# ## **0-3. 웹 사이트**
# - [바람돌이의 빅데이터] : [바람돌이/딥러닝] GCN 논문 리뷰 및 코드 리뷰 (Semi-Supervised Classification with Graph Convolutional Networks) | [[블로그 링크]](https://m.blog.naver.com/winddori2002/222183504185)
#
# - pytorch-geometric : COLAB NOTEBOOKS AND VIDEO TUTORIALS - 2. Node Classification with Graph Neural Networks | [[코랩 링크]](https://colab.research.google.com/drive/14OvFnAXggxB8vM4e8vSURUp1TaKnovzX?usp=sharing)
#
# - 아기여우의 자기계발 블로그 : Graph Neural Networks (GNN) / 그래프 뉴럴 네트워크 기초 개념 정리 | [[블로그 링크]](https://littlefoxdiary.tistory.com/16)
#
#
# - Seongsu : 예제를 통해 알아보는 PyTorch Geometric 5 Basic Concepts | [[블로그 링크]](https://baeseongsu.github.io/posts/pytorch-geometric-introduction/)
#
# ## **0-4. 데이터셋 출처**
# - tkipf github : pygcn | [[깃헙 링크]](https://github.com/tkipf/pygcn/tree/master/data/cora)
#
# # **1. GNN (Graph Neural Network)란**
# ## **1-1. GNN을 알기 전에 Graph란**
# - 그래프(Graph)는 노드와 간선으로 이루어진 구조
# ![image.png](data:image/png;base64,...)
#
# - 수학적으로 그래프 G는 노드 집합 V와 간선 집합 E로 구성된다.
#   - 간선 집합 E의 원소 간선 e는 두 개의 노드로 이루어진 순서가 있는 쌍이다.
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **1-2. torch로 먼저 구현해보자**
# - 이번 주제에서는 Cora 데이터 셋을 이용하였다.
#   - Cora 데이터 셋에서 노드가 머신러닝 논문을 나타내고, 간선이 논문 간의 인용 여부를 나타내는 인용 그래프이다.
#   - Cora 데이터 셋을 이용한 최종 목적은 각 논문을 7가지 범주 중 하나로 분류하는 것이다.
#   - 주로 Semi-supervised graph node classification을 위한 데이터 셋으로 사용된다.

# %%
# !cp -r "drive/MyDrive/Colab Notebooks/dataset/GCN/cora" cora

# %% [markdown]
# ### **1) 데이터 셋부터 불러와 전처리하고 필요한 함수를 정의해보자**

# %%
import scipy.sparse as sp
import networkx as nx
import numpy as np
import pickle
import torch
import os

# %%
class Utils:

  ## 데이터 불러오는 함수
  def load_data(path='./cora/', dataset = 'cora'):

    print(f'Loading {dataset} dataset..')
    idx_feat_lb = np.genfromtxt(f'{path}{dataset}.content', dtype = np.dtype(str))

    ## cora.content에 있는 데이터 구조는 [인덱스, 피쳐 벡터, 레이블]로 구성되어 있다.
    feats  = sp.csr_matrix(idx_feat_lb[:, 1: -1], dtype=np.float32)

    ## 레이블 데이터 원 핫 인코딩 시키기
    labels = Utils.encode_onehot(idx_feat_lb[:, -1])

    ## graph 구성하기
    idx     = np.array(idx_feat_lb[:, 0], dtype = np.int32)
    idx_map = {j : i for i, j in enumerate(idx)} 

    unordered_edges = np.genfromtxt(f'{path}{dataset}.cites', dtype = np.int32)
    edges = np.array(list(map(idx_map.get, unordered_edges.flatten())), 
                     dtype = np.int32).reshape(unordered_edges.shape)

    ## 인접행렬 정의
    adj = sp.coo_matrix((np.ones(edges.shape[0]), (edges[:, 0], edges[:, 1])), 
                        shape = (labels.shape[0], labels.shape[0]), dtype = np.float32)
    adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)

    feats = Utils.normalize(feats)
    adj   = Utils.normalize(adj + sp.eye(adj.shape[0]))

    ## 학습 데이터를 따로 분할하는 것이 아니라 전체 데이터에서 인덱스 값으로 잘라서 사용
    train_idx = torch.LongTensor(range(140))
    val_idx   = torch.LongTensor(range(200, 500))
    test_idx  = torch.LongTensor(range(500, 1500))

    feats   = torch.FloatTensor(np.array(feats.todense()))
    labels  = torch.LongTensor(np.where(labels)[1])
    adj     = Utils.sparse_mx_to_torch_sparse_tensor(adj)

    return adj, feats, labels, train_idx, val_idx, test_idx

  
  ## 레이블을 원 핫 인코딩 시켜주는 함수
  def encode_onehot(labels):

    classes = set(labels)
    
    classes_dict  = {class_ : np.identity(len(classes))[idx, : ] for idx, class_ in enumerate(classes)} 
    labels_onehot = np.array(list(map(classes_dict.get, labels)), dtype = np.int32)

    return labels_onehot


  ## sparse matrix의 열을 정규화 시켜주는 함수
  def normalize(mx):

    rowsum = np.array(mx.sum(1))
    r_inv  = np.power(rowsum, -1).flatten()
    
    r_inv[np.isinf(r_inv)] = 0.
    r_mat_inv = sp.diags(r_inv)

    mx = r_mat_inv.dot(mx)
    return mx

  ## 정확도 계산해주는 함수
  def accuracy(output, labels):
    
    preds   = output.max(1)[1].type_as(labels)
    correct = preds.eq(labels).double()
    correct = correct.sum()

    return correct /  len(labels)

  
  ## scipy sparse matrix를 sparse tensor로 변환해주는 함수
  def sparse_mx_to_torch_sparse_tensor(sparse_mx):

    sparse_mx = sparse_mx.tocoo().astype(np.float32)
    indices   = torch.from_numpy(
                      np.vstack((sparse_mx.row, sparse_mx.col)).astype(np.int64)
                    )
    values    = torch.from_numpy(sparse_mx.data)
    shape = torch.Size(sparse_mx.shape)

    return torch.sparse.FloatTensor(indices, values, shape)

# %% [markdown]
# ### **2) 레이어와 설계구조를 정의해보자**
# - 참고한 github에서 논문의 Simple GCN과 비슷하게 구현했다고 한다.
# - simple GCN이라고 해도 GNN 태스크가 굉장히 어려워서 복잡할 줄 알았는데, 생각보다 간단해서 놀랐다.

# %%
from torch.nn.modules.module import Module
from torch.nn.parameter import Parameter
import torch.nn.functional as F
import torch.nn as nn
import torch
import math

# %%
## Graph Convolution 레이어 구성
class GraphConv(Module):

  def __init__(self, in_feats, out_feats, bias = True):
    super(GraphConv, self).__init__()

    self.in_feats, self.out_feats = in_feats, out_feats
    self.weight = Parameter(torch.FloatTensor(in_feats, out_feats))
    self.fc     = nn.Linear(in_feats, out_feats)

    if bias: self.bias = Parameter(torch.FloatTensor(out_feats))
    else: self.register_param('bias', None)
    
    self.reset_params()


  def reset_params(self):
    stdv = 1. / math.sqrt(self.weight.size(1))
    self.weight.data.uniform_(-stdv, stdv)

    if self.bias is not None: self.bias.data.uniform_(-stdv, stdv)

  
  def forward(self, input, adj):
    support = torch.mm(input, self.weight)
    output  = torch.spmm(adj, support)

    if self.bias is not None: return output + self.bias
    else: return output


  def __repr__(self):
    return self.__class___.__name__ + '(' \
          + str(self.in_feats) + '->' + str(self.out_feats) + ')'


class GCN(Module):

  def __init__(self, n_feat, n_hid, n_class, dropout):

    super(GCN, self).__init__()

    self.gc1 = GraphConv(n_feat, n_hid)
    self.gc2 = GraphConv(n_hid, n_class)
    self.dropout = dropout


  def forward(self, x, adj):
    
    x = F.relu(self.gc1(x, adj))
    x = F.dropout(x, self.dropout, training = self.training)
    x = self.gc2(x, adj)

    return F.log_softmax(x, dim = 1)

# %% [markdown]
# ### **3) 학습을 돌려보자**

# %%
import torch.optim as optim
import numpy as np
import time

# %%
LR           = 5e-3
EPOCHS       = 1000
HIDDEN       = 16
DROP_OUT     = 0.3
WEIGHT_DECAY = 5e-4

# %%
cuda   = 'cuda' if torch.cuda.is_available() else 'cpu'
device = torch.device(cuda)

torch.manual_seed(99)
if cuda == 'cuda': torch.cuda.manual_seed(99)

# %%
## 데이터를 불러와보자
adj, feats, labels, train_idx, val_idx, test_idx = Utils.load_data()
model = GCN(
              n_feat  = feats.shape[1], n_hid = HIDDEN,
              n_class = labels.max().item() + 1, dropout = DROP_OUT 
            )

optimizer = optim.Adam(model.parameters(), lr = LR, weight_decay = 0.0 if WEIGHT_DECAY ==  None else WEIGHT_DECAY)
loss_func = F.nll_loss
# Out:
# Loading cora dataset..

# %%
if cuda == 'cuda':
  model.cuda()
  feats  = feats.cuda()
  adj    = adj.cuda()
  labels = labels.cuda()
  
  train_idx = train_idx.cuda()
  val_idx   = val_idx.cuda()
  test_idx  = test_idx.cuda()

# %%
def train(epoch):

  start_time = time.time()
  model.train()
  optimizer.zero_grad()

  output     = model(feats, adj)
  train_loss = loss_func(output[train_idx], labels[train_idx])
  train_acc  = Utils.accuracy(output[train_idx], labels[train_idx])
  
  train_loss.backward()
  optimizer.step() 

  val_loss = loss_func(output[val_idx], labels[val_idx])
  val_acc  = Utils.accuracy(output[val_idx], labels[val_idx])

  if epoch % 10 == 0:
    print(f'[Epoch: {epoch + 1} / {EPOCHS}]\n',
          f'train loss : {train_loss.item():.3f} | train accuracy : {train_acc.item():.3f}\n',
          f'valid loss : {val_loss.item():.3f} | valid accuracy: {val_acc.item():.3f}\n',
          f'time: {time.time() - start_time:.4f}s \n')

# %%
def test():
    model.eval()
    output = model(feats, adj)
    test_loss = loss_func(output[test_idx], labels[test_idx])
    test_acc  = Utils.accuracy(output[test_idx], labels[test_idx])
    print("Test set results:",
          f"loss= {test_loss.item():.4f}",
          f"accuracy= {test_acc.item():.4f}")

# %%
# Train model
t_total = time.time()
for epoch in range(EPOCHS): train(epoch)
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))

# Testing
test()
# Out:
# [Epoch: 1 / 1000]
#  train loss : 1.983 | train accuracy : 0.100
#  valid loss : 1.998 | valid accuracy: 0.103
#  time: 0.1740s
#
# [Epoch: 11 / 1000]
#  train loss : 1.902 | train accuracy : 0.236
#  valid loss : 1.924 | valid accuracy: 0.163
#  time: 0.0300s
#
# [Epoch: 21 / 1000]
#  train loss : 1.811 | train accuracy : 0.229
#  valid loss : 1.838 | valid accuracy: 0.163
#  time: 0.0193s
#
# [Epoch: 31 / 1000]
#  train loss : 1.754 | train accuracy : 0.421
#  valid loss : 1.777 | valid accuracy: 0.407
#  time: 0.0191s
#
# [Epoch: 41 / 1000]
#  train loss : 1.670 | train accuracy : 0.343
#  valid loss : 1.690 | valid accuracy: 0.360
#  time: 0.0243s
#
# [Epoch: 51 / 1000]
#  train loss : 1.596 | train accuracy : 0.400
#  valid loss : 1.657 | valid accuracy: 0.363
#  time: 0.0186s
#
# [Epoch: 61 / 1000]
#  train loss : 1.525 | train accuracy : 0.443
#  valid loss : 1.602 | valid accuracy: 0.443
#  time: 0.0184s
#
# [Epoch: 71 / 1000]
#  train loss : 1.412 | train accuracy : 0.529
#  valid loss : 1.517 | valid accuracy: 0.500
#  time: 0.0222s
#
# [Epoch: 81 / 1000]
#  train loss : 1.300 | train accuracy : 0.607
#  valid loss : 1.443 | valid accuracy: 0.510
#  time: 0.0188s
#
# [Epoch: 91 / 1000]
#  train loss : 1.237 | train accuracy : 0.671
#  valid loss : 1.401 | valid accuracy: 0.580
#  time: 0.0377s
#
# [Epoch: 101 / 1000]
#  train loss : 1.110 | train accuracy : 0.707
#  valid loss : 1.292 | valid accuracy: 0.637
#  time: 0.0135s
#
# [Epoch: 111 / 1000]
#  train loss : 1.023 | train accuracy : 0.743
#  valid loss : 1.247 | valid accuracy: 0.660
#  time: 0.0174s
#
# [Epoch: 121 / 1000]
#  train loss : 0.968 | train accuracy : 0.757
#  valid loss : 1.190 | valid accuracy: 0.697
#  time: 0.0121s
#
# [Epoch: 131 / 1000]
#  train loss : 0.882 | train accuracy : 0.821
#  valid loss : 1.129 | valid accuracy: 0.720
#  time: 0.0133s
#
# [Epoch: 141 / 1000]
#  train loss : 0.835 | train accuracy : 0.829
#  valid loss : 1.060 | valid accuracy: 0.773
#  time: 0.0120s
#
# [Epoch: 151 / 1000]
#  train loss : 0.759 | train accuracy : 0.879
#  valid loss : 1.032 | valid accuracy: 0.747
#  time: 0.0129s
#
# [Epoch: 161 / 1000]
#  train loss : 0.692 | train accuracy : 0.893
#  valid loss : 0.980 | valid accuracy: 0.770
#  time: 0.0149s
#
# [Epoch: 171 / 1000]
#  train loss : 0.654 | train accuracy : 0.914
#  valid loss : 0.930 | valid accuracy: 0.790
#  time: 0.0137s
#
# [Epoch: 181 / 1000]
#  train loss : 0.644 | train accuracy : 0.893
#  valid loss : 0.935 | valid accuracy: 0.773
#  time: 0.0130s
#
# [Epoch: 191 / 1000]
#  train loss : 0.575 | train accuracy : 0.921
#  valid loss : 0.883 | valid accuracy: 0.803
#  time: 0.0127s
#
# [Epoch: 201 / 1000]
#  train loss : 0.566 | train accuracy : 0.914
#  valid loss : 0.888 | valid accuracy: 0.780
#  time: 0.0126s
#
# [Epoch: 211 / 1000]
#  train loss : 0.543 | train accuracy : 0.921
#  valid loss : 0.859 | valid accuracy: 0.773
#  time: 0.0130s
#
# [Epoch: 221 / 1000]
#  train loss : 0.520 | train accuracy : 0.943
#  valid loss : 0.854 | valid accuracy: 0.777
#  time: 0.0135s
#
# [Epoch: 231 / 1000]
#  train loss : 0.521 | train accuracy : 0.914
#  valid loss : 0.842 | valid accuracy: 0.783
#  time: 0.0128s
#
# [Epoch: 241 / 1000]
#  train loss : 0.475 | train accuracy : 0.950
#  valid loss : 0.831 | valid accuracy: 0.793
#  time: 0.0132s
#
# [Epoch: 251 / 1000]
#  train loss : 0.444 | train accuracy : 0.943
#  valid loss : 0.781 | valid accuracy: 0.807
#  time: 0.0134s
#
# [Epoch: 261 / 1000]
#  train loss : 0.440 | train accuracy : 0.957
#  valid loss : 0.777 | valid accuracy: 0.817
#  time: 0.0137s
#
# [Epoch: 271 / 1000]
#  train loss : 0.410 | train accuracy : 0.957
#  valid loss : 0.796 | valid accuracy: 0.787
#  time: 0.0134s
#
# [Epoch: 281 / 1000]
#  train loss : 0.390 | train accuracy : 0.964
#  valid loss : 0.766 | valid accuracy: 0.820
#  time: 0.0137s
#
# [Epoch: 291 / 1000]
#  train loss : 0.407 | train accuracy : 0.957
#  valid loss : 0.787 | valid accuracy: 0.803
#  time: 0.0133s
#
# [Epoch: 301 / 1000]
#  train loss : 0.369 | train accuracy : 0.964
#  valid loss : 0.756 | valid accuracy: 0.790
#  time: 0.0132s
#
# [Epoch: 311 / 1000]
#  train loss : 0.389 | train accuracy : 0.957
#  valid loss : 0.784 | valid accuracy: 0.780
#  time: 0.0125s
#
# [Epoch: 321 / 1000]
#  train loss : 0.348 | train accuracy : 0.971
#  valid loss : 0.742 | valid accuracy: 0.780
#  time: 0.0128s
#
# [Epoch: 331 / 1000]
#  train loss : 0.369 | train accuracy : 0.957
#  valid loss : 0.747 | valid accuracy: 0.790
#  time: 0.0130s
#
# [Epoch: 341 / 1000]
#  train loss : 0.344 | train accuracy : 0.971
#  valid loss : 0.719 | valid accuracy: 0.823
#  time: 0.0126s
#
# [Epoch: 351 / 1000]
#  train loss : 0.350 | train accuracy : 0.964
#  valid loss : 0.740 | valid accuracy: 0.793
#  time: 0.0140s
#
# [Epoch: 361 / 1000]
#  train loss : 0.322 | train accuracy : 0.979
#  valid loss : 0.719 | valid accuracy: 0.793
#  time: 0.0142s
#
# [Epoch: 371 / 1000]
#  train loss : 0.301 | train accuracy : 0.971
#  valid loss : 0.733 | valid accuracy: 0.790
#  time: 0.0134s
#
# [Epoch: 381 / 1000]
#  train loss : 0.314 | train accuracy : 0.979
#  valid loss : 0.677 | valid accuracy: 0.830
#  time: 0.0143s
#
# [Epoch: 391 / 1000]
#  train loss : 0.322 | train accuracy : 0.950
#  valid loss : 0.703 | valid accuracy: 0.813
#  time: 0.0134s
#
# [Epoch: 401 / 1000]
#  train loss : 0.300 | train accuracy : 0.950
#  valid loss : 0.703 | valid accuracy: 0.823
#  time: 0.0141s
#
# [Epoch: 411 / 1000]
#  train loss : 0.294 | train accuracy : 0.971
#  valid loss : 0.727 | valid accuracy: 0.783
#  time: 0.0135s
#
# [Epoch: 421 / 1000]
#  train loss : 0.285 | train accuracy : 0.964
#  valid loss : 0.711 | valid accuracy: 0.793
#  time: 0.0134s
#
# [Epoch: 431 / 1000]
#  train loss : 0.275 | train accuracy : 0.971
#  valid loss : 0.694 | valid accuracy: 0.807
#  time: 0.0137s
#
# [Epoch: 441 / 1000]
#  train loss : 0.284 | train accuracy : 0.979
#  valid loss : 0.704 | valid accuracy: 0.800
#  time: 0.0135s
#
# [Epoch: 451 / 1000]
#  train loss : 0.271 | train accuracy : 0.986
#  valid loss : 0.698 | valid accuracy: 0.803
#  time: 0.0188s
#
# [Epoch: 461 / 1000]
#  train loss : 0.273 | train accuracy : 0.993
#  valid loss : 0.692 | valid accuracy: 0.817
#  time: 0.0158s
#
# [Epoch: 471 / 1000]
#  train loss : 0.272 | train accuracy : 0.979
#  valid loss : 0.684 | valid accuracy: 0.800
#  time: 0.0131s
#
# [Epoch: 481 / 1000]
#  train loss : 0.276 | train accuracy : 0.971
#  valid loss : 0.680 | valid accuracy: 0.810
#  time: 0.0138s
#
# [Epoch: 491 / 1000]
#  train loss : 0.263 | train accuracy : 0.986
#  valid loss : 0.661 | valid accuracy: 0.807
#  time: 0.0140s
#
# [Epoch: 501 / 1000]
#  train loss : 0.244 | train accuracy : 0.979
#  valid loss : 0.705 | valid accuracy: 0.790
#  time: 0.0138s
#
# [Epoch: 511 / 1000]
#  train loss : 0.269 | train accuracy : 0.986
#  valid loss : 0.705 | valid accuracy: 0.800
#  time: 0.0147s
#
# [Epoch: 521 / 1000]
#  train loss : 0.259 | train accuracy : 0.979
#  valid loss : 0.685 | valid accuracy: 0.787
#  time: 0.0130s
#
# [Epoch: 531 / 1000]
#  train loss : 0.248 | train accuracy : 0.971
#  valid loss : 0.681 | valid accuracy: 0.810
#  time: 0.0169s
#
# [Epoch: 541 / 1000]
#  train loss : 0.264 | train accuracy : 0.964
#  valid loss : 0.701 | valid accuracy: 0.790
#  time: 0.0138s
#
# [Epoch: 551 / 1000]
#  train loss : 0.260 | train accuracy : 0.964
#  valid loss : 0.696 | valid accuracy: 0.783
#  time: 0.0128s
#
# [Epoch: 561 / 1000]
#  train loss : 0.265 | train accuracy : 0.964
#  valid loss : 0.698 | valid accuracy: 0.793
#  time: 0.0130s
#
# [Epoch: 571 / 1000]
#  train loss : 0.252 | train accuracy : 0.986
#  valid loss : 0.681 | valid accuracy: 0.797
#  time: 0.0143s
#
# [Epoch: 581 / 1000]
#  train loss : 0.248 | train accuracy : 0.971
#  valid loss : 0.668 | valid accuracy: 0.800
#  time: 0.0127s
#
# [Epoch: 591 / 1000]
#  train loss : 0.241 | train accuracy : 0.971
#  valid loss : 0.681 | valid accuracy: 0.797
#  time: 0.0126s
#
# [Epoch: 601 / 1000]
#  train loss : 0.236 | train accuracy : 0.986
#  valid loss : 0.689 | valid accuracy: 0.787
#  time: 0.0133s
#
# [Epoch: 611 / 1000]
#  train loss : 0.243 | train accuracy : 0.964
#  valid loss : 0.680 | valid accuracy: 0.817
#  time: 0.0166s
#
# [Epoch: 621 / 1000]
#  train loss : 0.226 | train accuracy : 0.979
#  valid loss : 0.649 | valid accuracy: 0.813
#  time: 0.0156s
#
# [Epoch: 631 / 1000]
#  train loss : 0.223 | train accuracy : 0.986
#  valid loss : 0.688 | valid accuracy: 0.793
#  time: 0.0131s
#
# [Epoch: 641 / 1000]
#  train loss : 0.221 | train accuracy : 0.979
#  valid loss : 0.643 | valid accuracy: 0.797
#  time: 0.0152s
#
# [Epoch: 651 / 1000]
#  train loss : 0.230 | train accuracy : 0.979
#  valid loss : 0.688 | valid accuracy: 0.783
#  time: 0.0132s
#
# [Epoch: 661 / 1000]
#  train loss : 0.235 | train accuracy : 0.979
#  valid loss : 0.716 | valid accuracy: 0.770
#  time: 0.0132s
#
# [Epoch: 671 / 1000]
#  train loss : 0.203 | train accuracy : 0.979
#  valid loss : 0.673 | valid accuracy: 0.797
#  time: 0.0131s
#
# [Epoch: 681 / 1000]
#  train loss : 0.233 | train accuracy : 0.971
#  valid loss : 0.661 | valid accuracy: 0.793
#  time: 0.0127s
#
# [Epoch: 691 / 1000]
#  train loss : 0.200 | train accuracy : 0.993
#  valid loss : 0.680 | valid accuracy: 0.787
#  time: 0.0119s
#
# [Epoch: 701 / 1000]
#  train loss : 0.225 | train accuracy : 0.986
#  valid loss : 0.663 | valid accuracy: 0.797
#  time: 0.0136s
#
# [Epoch: 711 / 1000]
#  train loss : 0.226 | train accuracy : 0.971
#  valid loss : 0.671 | valid accuracy: 0.800
#  time: 0.0128s
#
# [Epoch: 721 / 1000]
#  train loss : 0.220 | train accuracy : 0.986
#  valid loss : 0.667 | valid accuracy: 0.793
#  time: 0.0124s
#
# [Epoch: 731 / 1000]
#  train loss : 0.218 | train accuracy : 0.993
#  valid loss : 0.675 | valid accuracy: 0.787
#  time: 0.0135s
#
# [Epoch: 741 / 1000]
#  train loss : 0.204 | train accuracy : 0.986
#  valid loss : 0.633 | valid accuracy: 0.820
#  time: 0.0125s
#
# [Epoch: 751 / 1000]
#  train loss : 0.227 | train accuracy : 0.979
#  valid loss : 0.676 | valid accuracy: 0.810
#  time: 0.0127s
#
# [Epoch: 761 / 1000]
#  train loss : 0.205 | train accuracy : 0.979
#  valid loss : 0.688 | valid accuracy: 0.817
#  time: 0.0128s
#
# [Epoch: 771 / 1000]
#  train loss : 0.229 | train accuracy : 1.000
#  valid loss : 0.693 | valid accuracy: 0.797
#  time: 0.0139s
#
# [Epoch: 781 / 1000]
#  train loss : 0.208 | train accuracy : 0.986
#  valid loss : 0.686 | valid accuracy: 0.787
#  time: 0.0135s
#
# [Epoch: 791 / 1000]
#  train loss : 0.206 | train accuracy : 0.979
#  valid loss : 0.667 | valid accuracy: 0.793
#  time: 0.0136s
#
# [Epoch: 801 / 1000]
#  train loss : 0.212 | train accuracy : 0.964
#  valid loss : 0.687 | valid accuracy: 0.800
#  time: 0.0132s
#
# [Epoch: 811 / 1000]
#  train loss : 0.226 | train accuracy : 0.986
#  valid loss : 0.675 | valid accuracy: 0.803
#  time: 0.0190s
#
# [Epoch: 821 / 1000]
#  train loss : 0.200 | train accuracy : 0.986
#  valid loss : 0.692 | valid accuracy: 0.793
#  time: 0.0123s
#
# [Epoch: 831 / 1000]
#  train loss : 0.190 | train accuracy : 0.979
#  valid loss : 0.681 | valid accuracy: 0.793
#  time: 0.0125s
#
# [Epoch: 841 / 1000]
#  train loss : 0.202 | train accuracy : 0.986
#  valid loss : 0.664 | valid accuracy: 0.817
#  time: 0.0127s
#
# [Epoch: 851 / 1000]
#  train loss : 0.206 | train accuracy : 0.971
#  valid loss : 0.626 | valid accuracy: 0.817
#  time: 0.0124s
#
# [Epoch: 861 / 1000]
#  train loss : 0.174 | train accuracy : 0.986
#  valid loss : 0.660 | valid accuracy: 0.810
#  time: 0.0123s
#
# [Epoch: 871 / 1000]
#  train loss : 0.173 | train accuracy : 0.993
#  valid loss : 0.690 | valid accuracy: 0.783
#  time: 0.0126s
#
# [Epoch: 881 / 1000]
#  train loss : 0.192 | train accuracy : 0.986
#  valid loss : 0.684 | valid accuracy: 0.777
#  time: 0.0130s
#
# [Epoch: 891 / 1000]
#  train loss : 0.197 | train accuracy : 0.986
#  valid loss : 0.690 | valid accuracy: 0.793
#  time: 0.0117s
#
# [Epoch: 901 / 1000]
#  train loss : 0.190 | train accuracy : 0.979
#  valid loss : 0.673 | valid accuracy: 0.813
#  time: 0.0134s
#
# [Epoch: 911 / 1000]
#  train loss : 0.196 | train accuracy : 0.979
#  valid loss : 0.668 | valid accuracy: 0.820
#  time: 0.0126s
#
# [Epoch: 921 / 1000]
#  train loss : 0.185 | train accuracy : 0.986
#  valid loss : 0.649 | valid accuracy: 0.777
#  time: 0.0126s
#
# [Epoch: 931 / 1000]
#  train loss : 0.184 | train accuracy : 0.993
#  valid loss : 0.674 | valid accuracy: 0.790
#  time: 0.0124s
#
# [Epoch: 941 / 1000]
#  train loss : 0.201 | train accuracy : 0.986
#  valid loss : 0.671 | valid accuracy: 0.800
#  time: 0.0130s
#
# [Epoch: 951 / 1000]
#  train loss : 0.189 | train accuracy : 0.993
#  valid loss : 0.650 | valid accuracy: 0.790
#  time: 0.0134s
#
# [Epoch: 961 / 1000]
#  train loss : 0.177 | train accuracy : 0.993
#  valid loss : 0.705 | valid accuracy: 0.787
#  time: 0.0143s
#
# [Epoch: 971 / 1000]
#  train loss : 0.182 | train accuracy : 0.993
#  valid loss : 0.678 | valid accuracy: 0.803
#  time: 0.0126s
#
# [Epoch: 981 / 1000]
#  train loss : 0.193 | train accuracy : 0.986
#  valid loss : 0.653 | valid accuracy: 0.800
#  time: 0.0133s
#
# [Epoch: 991 / 1000]
#  train loss : 0.171 | train accuracy : 0.993
#  valid loss : 0.652 | valid accuracy: 0.820
#  time: 0.0129s
#
# Optimization Finished!
# Total time elapsed: 15.4070s
# Test set results: loss= 0.6083 accuracy= 0.8250

# %% [markdown]
# ## **1-3. Pytorch Geometric을 이용하여 구현해보자**

# %%
# !nvcc -V
# !python -V

import torch
torch.__version__
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0
# Python 3.7.15
# '1.12.1+cu113'

# %%
# !pip install torch_geometric
# !pip install https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_sparse-0.6.15-cp37-cp37m-linux_x86_64.whl
# !pip install https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_scatter-2.0.9-cp37-cp37m-linux_x86_64.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch_geometric
#   Downloading torch_geometric-2.1.0.post1.tar.gz (467 kB)
#      |████████████████████████████████| 467 kB 5.1 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (1.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch_geometric) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch_geometric) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch_geometric) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch_geometric) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch_geometric) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch_geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch_geometric) (1.2.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.1.0.post1-py3-none-any.whl size=689859 sha256=7431dfb2753fb43bd68d7352dc321113d26b62944906e1f8e2407b546067c0b8
#   Stored in directory: /root/.cache/pip/wheels/d1/cb/43/f7f2e472de4d7cff31bceddadc36d634e1e545fbc17961c282
# Successfully built torch-geometric
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.1.0.post1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-sparse==0.6.15
#   Downloading https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_sparse-0.6.15-cp37-cp37m-linux_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 2.7 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-sparse==0.6.15) (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy->torch-sparse==0.6.15) (1.21.6)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.15
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-scatter==2.0.9
#   Downloading https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_scatter-2.0.9-cp37-cp37m-linux_x86_64.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 2.7 MB/s
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.9

# %% [markdown]
# ### **1) 그래프 데이터 핸들링**
# - Pytorch Geometric에서 하나의 그래프는 torch_geometric.data.Data라는 클래스로 표현되고, 다음과 같은 인자를 받는다.
# ⚠️ 아래의 인자값들은 옵션으로, 자신이 구성하고 싶은 속성을 다양하게 모델링 할 수 있다.
#
# |인자값|설명|
# |:--|:--|
# |x|노드의 특징 행렬|
# |edge_index|그래프의 연결성 (인접행렬)|
# |edge_attr|엣지 특징 행렬|
# |y|target 값|
# |pos| 노드 위치 행렬|

# %%
from torch_geometric.data import Data

# %% [markdown]
# - Data를 통해 그래프를 정의하는 방법은 두 가지가 있다.
#   1) n x 2 형태의 텐서로 정의하는 방법
#   2) (v1, v2) 순서 쌍으로 정의하는 방법
#      -> edge_index를 전치 시킨 후, contiguous()함수를 통해 1)번과 같은 형태로 만든다.

# %%
edge_idx = torch.tensor([[0, 1, 1, 2],
                         [1, 0, 2, 1]], dtype = torch.long)

x    = torch.tensor([[-1], [0], [1]], dtype = torch.float)
data = Data(x = x, edge_index = edge_idx)

data
# Out:
# Data(x=[3, 1], edge_index=[2, 4])

# %%
## 그래프의 연결 정보. 0 <->1 <-> 2 이렇게 연결되어 있는 그래프이다.
edge_idx = torch.tensor([[0, 1],
                         [1, 0],
                         [1, 2],
                         [2, 1]], dtype = torch.long)

## 노드들의 특징 행렬
x    = torch.tensor([[-1], [0], [1]], dtype = torch.float)
data = Data(x = x, edge_index = edge_idx.t().contiguous()) 

data
# Out:
# Data(x=[3, 1], edge_index=[2, 4])

# %% [markdown]
# - torch_geometric.data.Data는 다음과 같은 함수도 제공한다.
#
# |함수명|설명|
# |:--|:--|
# |data.keys|해당 속성 이름|
# |data.num_nodes|총 노드 개수|
# |data.num_edges|총 엣지 개수|
# |data.has_isolated_nodes()|고립 노드 여부 확인|
# |data.has_self_loops()|셀프 루프 포함 여부 확인|
# |data.is_directed()|그래프의 방향성 여부 확인|

# %%
print(f'data keys       : {data.keys} \nnumber of nodes : {data.num_nodes} \nnumber of edges : {data.num_edges}\n')
print(f'has isolated nodes? : {data.has_isolated_nodes()}')
print(f'has self loops?     : {data.has_self_loops()}')
print(f'is graph directed?  : {data.is_directed()}')
# Out:
# data keys       : ['x', 'edge_index']
# number of nodes : 3
# number of edges : 4
#
# has isolated nodes? : False
# has self loops?     : False
# is graph directed?  : False

# %% [markdown]
# ### **2) Cora 데이터 셋을 불러와 분석해보자**
# - torch_geometric.datasets에는 Cora, Enzymes 등 많은 데이터 셋이 담겨있다.
# - 다운로드 부터 전처리까지 모두 해주어 데이터 관련해서는 크게 신경 쓸 부분은 없는것 같다.

# %%
from torch_geometric.datasets import Planetoid
from torch_geometric.utils import to_networkx
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import networkx as nx

# %%
dataset = Planetoid(root = './Cora', name = 'Cora')

# %%
print(f'length of dataset         : {len(dataset)}')
print(f'num classes in dataset    : {dataset.num_classes}')
print(f'num node feature in graph : {dataset.num_node_features}')
# Out:
# length of dataset         : 1
# num classes in dataset    : 7
# num node feature in graph : 1433

# %%
data = dataset[0]

print(f'is graph directed?    : {data.is_directed()}')

## data.train_mask | 학습용 노드 데이터 ([True, True, ..., False] 형태로 들어있음.)
## data.val_mask   | 검증용 노드 데이터 ([True, True, ..., False] 형태로 들어있음.)
## data.test_mask  | 시험용 노드 데이터 ([True, True, ..., False] 형태로 들어있음.)

print(f'number of train nodes : {data.train_mask.sum().item()}')
print(f'number of valid nodes : {data.val_mask.sum().item()}')
print(f'number of test  nodes : {data.test_mask.sum().item()}')
# Out:
# is graph directed?    : False
# number of train nodes : 140
# number of valid nodes : 500
# number of test  nodes : 1000

# %% [markdown]
# #### **a. 데이터 셋에 있는 그래프를 그려보자**

# %%
## 데이터 셋에서의 그래프를 보여주는 함수
def visualize_graph(G, color):

  plt.figure(figsize = (7, 7))
  plt.xticks([])
  plt.yticks([])

  nx.draw_networkx(G, pos = nx.spring_layout(G, seed = 99), with_labels = False,
                   node_color = color, cmap = 'Set2')
  
  plt.show()

## 학습하는 중의 그래프를 보여주는 함수
def visualize_embedding(output, color, epoch = None, loss = None):

  plt.figure(figsize = (7, 7))
  plt.xticks([])
  plt.yticks([])

  output = output.detach().cpu().numpy()
  output = TSNE(n_components = 2).fit_transform(output)

  plt.scatter(output[:,0], output[:,1], s = 70, c = color, cmap = 'Set2')
  
  condition = [epoch is not None, loss is not None]
  if all(condition): plt.xlabel(f'Epoch | {epoch}, Loss : {loss.item():.4f}, fontsize = 16')

  plt.show()

# %%
G = to_networkx(data, to_undirected = data.is_undirected())
visualize_graph(G, data.y)

# %% [markdown]
# ### **3) 신경망을 구성하고 학습해보자**
# - torch_geometric에는 GCNConv, GCN2Conv 등 다양한 신경망들이 구현되어 있다.
# - 내부코드를 들어가 확인해보니 Linear층 하나로만 구성되어 있었다.

# %%
from torch_geometric.nn import GCNConv
from torch.nn import Linear

# %%
class GeometricGCN(Module):

  def __init__(self):

    super(GeometricGCN, self).__init__()
    self.conv1 = GCNConv(dataset.num_node_features, 16)
    self.conv2 = GCNConv(16, dataset.num_classes)

  def forward(self, data):

    x, edge_idx = data.x, data.edge_index
    x = self.conv1(x, edge_idx).relu()
    x = F.dropout(x, p = DROP_OUT, training = self.training)
    x = self.conv2(x, edge_idx)

    return x

# %%
model     = GeometricGCN().to(device)
data      = dataset[0].to(device)
optimizer = optim.Adam(model.parameters(), lr = LR, weight_decay = WEIGHT_DECAY)
loss_func = nn.CrossEntropyLoss()

# %%
output = model(data)
visualize_embedding(output, data.y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
model.train()
for epoch in range(EPOCHS):

  optimizer.zero_grad()
  out = model(data)

  train_loss = loss_func(out[data.train_mask], data.y[data.train_mask])
  train_acc  = Utils.accuracy(out[data.train_mask], data.y[data.train_mask])

  train_loss.backward()
  optimizer.step() 

  val_loss = loss_func(out[data.val_mask], data.y[data.val_mask])
  val_acc  = Utils.accuracy(out[data.val_mask], data.y[data.val_mask])

  if (epoch % 100 == 0) or (epoch == EPOCHS - 1):
    print(f'[Epoch: {epoch + 1} / {EPOCHS}]\n',
      f'train loss : {train_loss.item():.3f} | train accuracy : {train_acc.item():.3f}\n',
      f'valid loss : {val_loss.item():.3f} | valid accuracy: {val_acc.item():.3f}\n')
    
    visualize_embedding(out, color = data.y, epoch = epoch, loss = val_loss)
# Out:
# [Epoch: 1 / 1000]
#  train loss : 1.946 | train accuracy : 0.150
#  valid loss : 1.934 | valid accuracy: 0.174
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [Epoch: 101 / 1000]
#  train loss : 0.031 | train accuracy : 1.000
#  valid loss : 0.834 | valid accuracy: 0.744
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [Epoch: 201 / 1000]
#  train loss : 0.026 | train accuracy : 1.000
#  valid loss : 0.815 | valid accuracy: 0.770
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [Epoch: 301 / 1000]
#  train loss : 0.017 | train accuracy : 1.000
#  valid loss : 0.849 | valid accuracy: 0.748
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [Epoch: 401 / 1000]
#  train loss : 0.014 | train accuracy : 1.000
#  valid loss : 0.847 | valid accuracy: 0.760
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [Epoch: 501 / 1000]
#  train loss : 0.010 | train accuracy : 1.000
#  valid loss : 0.838 | valid accuracy: 0.754
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [Epoch: 601 / 1000]
#  train loss : 0.010 | train accuracy : 1.000
#  valid loss : 0.789 | valid accuracy: 0.760
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [Epoch: 701 / 1000]
#  train loss : 0.015 | train accuracy : 1.000
#  valid loss : 0.862 | valid accuracy: 0.756
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [Epoch: 801 / 1000]
#  train loss : 0.011 | train accuracy : 1.000
#  valid loss : 0.864 | valid accuracy: 0.770
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [Epoch: 901 / 1000]
#  train loss : 0.010 | train accuracy : 1.000
#  valid loss : 0.906 | valid accuracy: 0.732
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [Epoch: 1000 / 1000]
#  train loss : 0.013 | train accuracy : 1.000
#  valid loss : 0.883 | valid accuracy: 0.754
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
test_loss = loss_func(out[data.test_mask], data.y[data.test_mask])
test_acc  = Utils.accuracy(out[data.test_mask], data.y[data.test_mask])

print(f'test loss : {test_loss.item():.3f} | test accuracy : {test_acc.item():.3f}\n')

visualize_embedding(out, color = data.y, epoch = epoch, loss = val_loss)
# Out:
# test loss : 0.708 | test accuracy : 0.794
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
